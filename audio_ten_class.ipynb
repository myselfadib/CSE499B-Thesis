# %%
import os
import torch
import torch.nn.functional as F
from torch.nn import init
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import pandas as pd

# Define your directories
root_dir = os.path.expanduser("~")
audio_dir = "audio_mod"
save_dir = "audio_ten_models"
if not os.path.exists(save_dir):
    os.makedirs(save_dir)

# %%
import os
import glob
import pandas as pd
# Scan the directory and prepare a list of all the audio file paths
audio_files = glob.glob(os.path.join(audio_dir, '**/*.wav'), recursive=True)

# Extract the class label from each file name or from the name of the parent sub-folder
# This assumes that your class labels are the names of the parent sub-folders
class_labels = [os.path.basename(os.path.dirname(file)) for file in audio_files]

# Map each class name from text to a numeric class ID
# This creates a dictionary where the keys are your class labels and the values are unique integers
class_dict = {label: idx for idx, label in enumerate(set(class_labels))}
class_ids = [class_dict[label] for label in class_labels]
class_names = list(class_dict.keys())
# Extract the file name and its parent folder name from each audio file path
relative_paths = [os.path.join(os.path.basename(os.path.dirname(file)), os.path.basename(file)) for file in audio_files]

# Create a DataFrame
df = pd.DataFrame({
    'relative_path': relative_paths,
    'classID': class_ids
})

df.head(100)
# Out:
#               relative_path  classID
# 0        baari\baari_01.wav        2
# 1        baari\baari_02.wav        2
# 2        baari\baari_03.wav        2
# 3        baari\baari_04.wav        2
# 4        baari\baari_05.wav        2
# ..                      ...      ...
# 95  bondhu\bondhu_mahim.wav        1
# 96  bondhu\bondhu_masum.wav        1
# 97  bondhu\bondhu_ramim.wav        1
# 98   bondhu\bondhu_riaz.wav        1
# 99  bondhu\p10_c_bondhu.wav        1
#
# [100 rows x 2 columns]

# %%
num_classes = df['classID'].nunique()
print(f'There are {num_classes} unique classes in the DataFrame.')
# Out:
# There are 10 unique classes in the DataFrame.

# %%
import math, random
import torch
import torchaudio
from torchaudio import transforms
from IPython.display import Audio

class AudioUtil():
  # ----------------------------
  # Load an audio file. Return the signal as a tensor and the sample rate
  # ----------------------------
  @staticmethod
  def open(audio_file):
    sig, sr = torchaudio.load(audio_file)
    return (sig, sr)
  # Convert the given audio to the desired number of channels
  # ----------------------------
  @staticmethod
  def rechannel(aud, new_channel):
    sig, sr = aud

    if (sig.shape[0] == new_channel):
      # Nothing to do
      return aud

    if (new_channel == 1):
      # Convert from stereo to mono by selecting only the first channel
      resig = sig[:1, :]
    else:
      # Convert from mono to stereo by duplicating the first channel
      resig = torch.cat([sig, sig])

    return ((resig, sr))

      # Since Resample applies to a single channel, we resample one channel at a time
  # ----------------------------
  @staticmethod
  def resample(aud, newsr):
    sig, sr = aud

    if (sr == newsr):
      # Nothing to do
      return aud

    num_channels = sig.shape[0]
    # Resample first channel
    resig = torchaudio.transforms.Resample(sr, newsr)(sig[:1,:])
    if (num_channels > 1):
      # Resample the second channel and merge both channels
      retwo = torchaudio.transforms.Resample(sr, newsr)(sig[1:,:])
      resig = torch.cat([resig, retwo])

    return ((resig, newsr))

    # Pad (or truncate) the signal to a fixed length 'max_ms' in milliseconds
  # ----------------------------
  @staticmethod
  def pad_trunc(aud, max_ms):
    sig, sr = aud
    num_rows, sig_len = sig.shape
    max_len = sr//1000 * max_ms

    if (sig_len > max_len):
      # Truncate the signal to the given length
      sig = sig[:,:max_len]

    elif (sig_len < max_len):
      # Length of padding to add at the beginning and end of the signal
      pad_begin_len = random.randint(0, max_len - sig_len)
      pad_end_len = max_len - sig_len - pad_begin_len

      # Pad with 0s
      pad_begin = torch.zeros((num_rows, pad_begin_len))
      pad_end = torch.zeros((num_rows, pad_end_len))

      sig = torch.cat((pad_begin, sig, pad_end), 1)

    return (sig, sr)

      # Shifts the signal to the left or right by some percent. Values at the end
  # are 'wrapped around' to the start of the transformed signal.
  # ----------------------------
  @staticmethod
  def time_shift(aud, shift_limit):
    sig,sr = aud
    _, sig_len = sig.shape
    shift_amt = int(random.random() * shift_limit * sig_len)
    return (sig.roll(shift_amt), sr)

      # ----------------------------
  # Generate a Spectrogram
  # ----------------------------
  @staticmethod
  def spectro_gram(aud, n_mels=64, n_fft=1024, hop_len=None):
    sig,sr = aud
    top_db = 80

    # spec has shape [channel, n_mels, time], where channel is mono, stereo etc
    spec = transforms.MelSpectrogram(sr, n_fft=n_fft, hop_length=hop_len, n_mels=n_mels)(sig)

    # Convert to decibels
    spec = transforms.AmplitudeToDB(top_db=top_db)(spec)
    return (spec)

     # Augment the Spectrogram by masking out some sections of it in both the frequency
  # dimension (ie. horizontal bars) and the time dimension (vertical bars) to prevent
  # overfitting and to help the model generalise better. The masked sections are
  # replaced with the mean value.
  # ----------------------------
  @staticmethod
  def spectro_augment(spec, max_mask_pct=0.1, n_freq_masks=1, n_time_masks=1):
    _, n_mels, n_steps = spec.shape
    mask_value = spec.mean()
    aug_spec = spec

    freq_mask_param = max_mask_pct * n_mels
    for _ in range(n_freq_masks):
      aug_spec = transforms.FrequencyMasking(freq_mask_param)(aug_spec, mask_value)

    time_mask_param = max_mask_pct * n_steps
    for _ in range(n_time_masks):
      aug_spec = transforms.TimeMasking(time_mask_param)(aug_spec, mask_value)

    return aug_spec

# %%
from torch.utils.data import DataLoader, Dataset, random_split
import torchaudio

# ----------------------------
# Sound Dataset
# ----------------------------
class SoundDS(Dataset):
  def __init__(self, df, data_path):
    self.df = df
    self.data_path = str(data_path)
    self.duration = 4000
    self.sr = 44100
    self.channel = 2
    self.shift_pct = 0.4

  # ----------------------------
  # Number of items in dataset
  # ----------------------------
  def __len__(self):
    return len(self.df)

  # ----------------------------
  # Get i'th item in dataset
  # ----------------------------
  def __getitem__(self, idx):
    # Absolute file path of the audio file - concatenate the audio directory with
    # the relative path
    audio_file = self.data_path + self.df.loc[idx, 'relative_path']
    # Get the Class ID
    class_id = self.df.loc[idx, 'classID']

    aud = AudioUtil.open(audio_file)
    # Some sounds have a higher sample rate, or fewer channels compared to the
    # majority. So make all sounds have the same number of channels and same
    # sample rate. Unless the sample rate is the same, the pad_trunc will still
    # result in arrays of different lengths, even though the sound duration is
    # the same.
    reaud = AudioUtil.resample(aud, self.sr)
    rechan = AudioUtil.rechannel(reaud, self.channel)

    dur_aud = AudioUtil.pad_trunc(rechan, self.duration)
    shift_aud = AudioUtil.time_shift(dur_aud, self.shift_pct)
    sgram = AudioUtil.spectro_gram(shift_aud, n_mels=64, n_fft=1024, hop_len=None)
    aug_sgram = AudioUtil.spectro_augment(sgram, max_mask_pct=0.1, n_freq_masks=2, n_time_masks=2)

    return aug_sgram, class_id

# %%
from torch.utils.data import random_split

# Define your audio directory
#data_path = os.path.join(os.path.expanduser("~"), "Desktop", "cse499b", "audio_mod/")
data_path = "E:/cse499b/audio_mod/"
myds = SoundDS(df, data_path)

# Random split of 80:20 between training and validation
num_items = len(myds)
num_train = round(num_items * 0.8)
num_val = num_items - num_train
train_ds, val_ds = random_split(myds, [num_train, num_val])

# Create training and validation data loaders
train_dl = torch.utils.data.DataLoader(train_ds, batch_size=64, shuffle=True)
val_dl = torch.utils.data.DataLoader(val_ds, batch_size=64, shuffle=False)

# %%
import torch.nn.functional as F
from torch.nn import init
import torch.nn as nn

# ----------------------------
# Audio Classification Model
# ----------------------------
class AudioClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        conv_layers = []

        # First Convolution Block
        self.conv1 = nn.Conv2d(2, 8, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2))
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm2d(8)
        init.kaiming_normal_(self.conv1.weight, a=0.1)
        self.conv1.bias.data.zero_()
        conv_layers += [self.conv1, self.relu1, self.bn1]

        # Second Convolution Block
        self.conv2 = nn.Conv2d(8, 16, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm2d(16)
        init.kaiming_normal_(self.conv2.weight, a=0.1)
        self.conv2.bias.data.zero_()
        conv_layers += [self.conv2, self.relu2, self.bn2]

        # Third Convolution Block
        self.conv3 = nn.Conv2d(16, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu3 = nn.ReLU()
        self.bn3 = nn.BatchNorm2d(32)
        init.kaiming_normal_(self.conv3.weight, a=0.1)
        self.conv3.bias.data.zero_()
        conv_layers += [self.conv3, self.relu3, self.bn3]

        # Fourth Convolution Block
        self.conv4 = nn.Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu4 = nn.ReLU()
        self.bn4 = nn.BatchNorm2d(64)
        init.kaiming_normal_(self.conv4.weight, a=0.1)
        self.conv4.bias.data.zero_()
        conv_layers += [self.conv4, self.relu4, self.bn4]

        # Fifth Convolution Block
        self.conv5 = nn.Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
        self.relu5 = nn.ReLU()
        self.bn5 = nn.BatchNorm2d(128)
        init.kaiming_normal_(self.conv5.weight, a=0.1)
        self.conv5.bias.data.zero_()
        conv_layers += [self.conv5, self.relu5, self.bn5]

        # Linear Classifier
        self.ap = nn.AdaptiveAvgPool2d(output_size=1)
        self.lin = nn.Linear(in_features=128, out_features=10)

        # Wrap the Convolutional Blocks
        self.conv = nn.Sequential(*conv_layers)

    def forward(self, x):
        # Run the convolutional blocks
        x = self.conv(x)

        # Adaptive pool and flatten for input to linear layer
        x = self.ap(x)
        x = x.view(x.shape[0], -1)

        # Linear layer
        x = self.lin(x)

        # Final output
        return x



# Create the model and put it on the GPU if available
myModel = AudioClassifier()
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
myModel = myModel.to(device)
# Check that it is on Cuda
next(myModel.parameters()).device
# Out:
# device(type='cpu')

# %%
from torchsummary import summary
# Use torchsummary to print the model summary
summary(myModel, input_size=(2, 64, 64))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 8, 32, 32]             408
#             Conv2d-2            [-1, 8, 32, 32]             408
#               ReLU-3            [-1, 8, 32, 32]               0
#               ReLU-4            [-1, 8, 32, 32]               0
#        BatchNorm2d-5            [-1, 8, 32, 32]              16
#        BatchNorm2d-6            [-1, 8, 32, 32]              16
#             Conv2d-7           [-1, 16, 16, 16]           1,168
#             Conv2d-8           [-1, 16, 16, 16]           1,168
#               ReLU-9           [-1, 16, 16, 16]               0
#              ReLU-10           [-1, 16, 16, 16]               0
#       BatchNorm2d-11           [-1, 16, 16, 16]              32
#       BatchNorm2d-12           [-1, 16, 16, 16]              32
#            Conv2d-13             [-1, 32, 8, 8]           4,640
#            Conv2d-14             [-1, 32, 8, 8]           4,640
#              ReLU-15             [-1, 32, 8, 8]               0
#              ReLU-16             [-1, 32, 8, 8]               0
#       BatchNorm2d-17             [-1, 32, 8, 8]              64
#       BatchNorm2d-18             [-1, 32, 8, 8]              64
#            Conv2d-19             [-1, 64, 4, 4]          18,496
#            Conv2d-20             [-1, 64, 4, 4]          18,496
#              ReLU-21             [-1, 64, 4, 4]               0
#              ReLU-22             [-1, 64, 4, 4]               0
#       BatchNorm2d-23             [-1, 64, 4, 4]             128
#       BatchNorm2d-24             [-1, 64, 4, 4]             128
#            Conv2d-25            [-1, 128, 2, 2]          73,856
#            Conv2d-26            [-1, 128, 2, 2]          73,856
#              ReLU-27            [-1, 128, 2, 2]               0
#              ReLU-28            [-1, 128, 2, 2]               0
#       BatchNorm2d-29            [-1, 128, 2, 2]             256
#       BatchNorm2d-30            [-1, 128, 2, 2]             256
# AdaptiveAvgPool2d-31            [-1, 128, 1, 1]               0
#            Linear-32                   [-1, 10]           1,290
# ================================================================
# Total params: 199,418
# Trainable params: 199,418
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.03
# Forward/backward pass size (MB): 0.73
# Params size (MB): 0.76
# Estimated Total Size (MB): 1.52
# ----------------------------------------------------------------

# %%
import os
import torch
import torch.nn.functional as F
from torch.nn import init
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset, random_split
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns
import pandas as pd
import time
# Assuming device is defined, e.g., device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

def save_metrics(metrics, epoch, filepath):
    """ Save metrics in a CSV file for each epoch. """
    df = pd.DataFrame(metrics)
    df.to_csv(filepath, mode='a', header=not os.path.exists(filepath), index=False)

import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import normalize
import numpy as np
import os
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import numpy as np
import os

def plot_confusion_matrix(predictions, labels, save_dir, class_names):
    """Plot a detailed confusion matrix with absolute values in each cell."""
    cm = confusion_matrix(labels, predictions)
    
    # Normalizing the confusion matrix by the number of samples in each actual class
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(14, 14))  # Adjusting figure size for better fit
    sns.set(font_scale=1.4)  # Scaling fonts to match the new figure size
    ax = sns.heatmap(cm_normalized, annot=True, fmt=".2%", cmap="Blues",
                     xticklabels=class_names, yticklabels=class_names,
                     square=True, annot_kws={"size": 10}, cbar_kws={"fraction": 0.046, "pad": 0.04})

    plt.title('Normalized Confusion Matrix')
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')

    # Rotating the labels for better readability
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)

    plt.tight_layout()  # Ensuring nothing is cut off
    plt.savefig(os.path.join(save_dir, 'normalized_confusion_matrix.png'))
    plt.show()

# Example usage might go here if necessary





    
def plot_metrics(metrics):
    """ Plot training and validation loss and accuracy. """
    fig, axs = plt.subplots(2, figsize=(12, 10))
    axs[0].plot(metrics['train_loss'], label='Train Loss')
    axs[0].plot(metrics['val_loss'], label='Validation Loss')
    axs[0].set_xlabel('Epochs')
    axs[0].set_ylabel('Loss')
    axs[0].legend()
    axs[1].plot(metrics['train_accuracy'], label='Train Accuracy')
    axs[1].plot(metrics['val_accuracy'], label='Validation Accuracy')
    axs[1].set_xlabel('Epochs')
    axs[1].set_ylabel('Accuracy')
    axs[1].legend()
    plt.savefig(os.path.join(save_dir, 'training_validation_metrics.png'))

def evaluate(model, dataloader, criterion):
    model.eval()
    running_loss = 0.0
    total_prediction = 0
    correct_prediction = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for data in dataloader:
            inputs, labels = data[0].to(device), data[1].to(device)
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            _, prediction = torch.max(outputs, 1)
            correct_prediction += (prediction == labels).sum().item()
            total_prediction += prediction.shape[0]
            all_preds.extend(prediction.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    avg_loss = running_loss / len(dataloader)
    accuracy = correct_prediction / total_prediction
    class_report = classification_report(all_labels, all_preds, output_dict=True, zero_division=0)
    return {
        'loss': avg_loss,
        'accuracy': accuracy,
        'all_preds': all_preds,
        'all_labels': all_labels,
        'f1': class_report['macro avg']['f1-score'],
        'precision': class_report['macro avg']['precision'],
        'recall': class_report['macro avg']['recall']
    }

def training(model, train_dl, val_dl, num_epochs, device, class_names):
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
    scheduler = torch.optim.lr_scheduler.OneCycleLR(optimizer, max_lr=0.001, steps_per_epoch=len(train_dl), epochs=num_epochs, anneal_strategy='linear')

    best_val_accuracy = 0.0
    metrics = {
        'train_loss': [],
        'train_accuracy': [],
        'val_loss': [],
        'val_accuracy': [],
        'f1': [],
        'precision': [],
        'recall': []
    }
    start_time = time.time()  # Start time of the whole training process

    for epoch in range(num_epochs):
        epoch_start = time.time()  # Start time of the current epoch
        model.train()
        train_loss, train_correct, train_total = 0, 0, 0
        for inputs, labels in train_dl:
            inputs, labels = inputs.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()
            scheduler.step()
            train_loss += loss.item()
            train_correct += (outputs.argmax(1) == labels).type(torch.float).sum().item()
            train_total += labels.size(0)

        train_loss /= len(train_dl)
        train_accuracy = train_correct / train_total
        eval_results = evaluate(model, val_dl, criterion)

        # Collect metrics for plotting and analysis
        metrics['train_loss'].append(train_loss)
        metrics['train_accuracy'].append(train_accuracy)
        metrics['val_loss'].append(eval_results['loss'])
        metrics['val_accuracy'].append(eval_results['accuracy'])
        metrics['f1'].append(eval_results['f1'])
        metrics['precision'].append(eval_results['precision'])
        metrics['recall'].append(eval_results['recall'])

        # Save predictions and labels for the best model
        if eval_results['accuracy'] > best_val_accuracy:
            best_val_accuracy = eval_results['accuracy']
            model_path = os.path.join(save_dir, "audio_model_best.pth")
            torch.save(model.state_dict(), model_path)
            np.save(os.path.join(save_dir, 'predictions.npy'), np.array(eval_results['all_preds']))
            np.save(os.path.join(save_dir, 'labels.npy'), np.array(eval_results['all_labels']))

        epoch_time = time.time() - epoch_start  # Time taken for the current epoch
        print(f'Epoch {epoch+1}/{num_epochs}, Train Loss: {train_loss:.4f}, Train Acc: {train_accuracy:.4f}, Val Loss: {eval_results["loss"]:.4f}, Val Acc: {eval_results["accuracy"]:.4f}')
        print(f"Epoch Duration: {epoch_time:.2f} seconds")

    total_training_time = time.time() - start_time  # Total training time
    print(f"Total Training Time: {total_training_time:.2f} seconds")

    # Save the final metrics for further analysis if needed
    save_metrics(metrics, 'final', os.path.join(save_dir, 'final_metrics.csv'))

    # Load the best model for final evaluation
    model.load_state_dict(torch.load(model_path))
    plot_metrics(metrics)

    # Load predictions and labels for the confusion matrix
    predictions, labels = np.load(os.path.join(save_dir, 'predictions.npy')), np.load(os.path.join(save_dir, 'labels.npy'))
    plot_confusion_matrix(predictions, labels, save_dir, class_names)

    print("Final Evaluation on Validation Set:")
    print(f"Accuracy: {metrics['val_accuracy'][-1]:.4f}")
    print(f"Precision: {metrics['precision'][-1]:.4f}")
    print(f"Recall: {metrics['recall'][-1]:.4f}")
    print(f"F1-Score: {metrics['f1'][-1]:.4f}")

# Usage
num_epochs = 500  # Modify as necessary
training(myModel, train_dl, val_dl, num_epochs, device, class_names)
# Out:
# Epoch 1/500, Train Loss: 2.3533, Train Acc: 0.0785, Val Loss: 2.5437, Val Acc: 0.1047
# Epoch Duration: 26.82 seconds
# Epoch 2/500, Train Loss: 2.3276, Train Acc: 0.1076, Val Loss: 2.3523, Val Acc: 0.0930
# Epoch Duration: 11.85 seconds
# Epoch 3/500, Train Loss: 2.3050, Train Acc: 0.0930, Val Loss: 2.3049, Val Acc: 0.1279
# Epoch Duration: 12.80 seconds
# Epoch 4/500, Train Loss: 2.2979, Train Acc: 0.1134, Val Loss: 2.2973, Val Acc: 0.0814
# Epoch Duration: 18.87 seconds
# Epoch 5/500, Train Loss: 2.2811, Train Acc: 0.1105, Val Loss: 2.2652, Val Acc: 0.1279
# Epoch Duration: 16.78 seconds
# Epoch 6/500, Train Loss: 2.2602, Train Acc: 0.1366, Val Loss: 2.2683, Val Acc: 0.1163
# Epoch Duration: 14.58 seconds
# Epoch 7/500, Train Loss: 2.2481, Train Acc: 0.1337, Val Loss: 2.2459, Val Acc: 0.1163
# Epoch Duration: 15.85 seconds
# Epoch 8/500, Train Loss: 2.2578, Train Acc: 0.1686, Val Loss: 2.2346, Val Acc: 0.1279
# Epoch Duration: 14.52 seconds
# Epoch 9/500, Train Loss: 2.2249, Train Acc: 0.1802, Val Loss: 2.2522, Val Acc: 0.1512
# Epoch Duration: 15.53 seconds
# Epoch 10/500, Train Loss: 2.2394, Train Acc: 0.1686, Val Loss: 2.2237, Val Acc: 0.1395
# Epoch Duration: 14.62 seconds
# Epoch 11/500, Train Loss: 2.2161, Train Acc: 0.1715, Val Loss: 2.2383, Val Acc: 0.0930
# Epoch Duration: 15.88 seconds
# Epoch 12/500, Train Loss: 2.2173, Train Acc: 0.2122, Val Loss: 2.2494, Val Acc: 0.1163
# Epoch Duration: 14.61 seconds
# Epoch 13/500, Train Loss: 2.2206, Train Acc: 0.1686, Val Loss: 2.2572, Val Acc: 0.0814
# Epoch Duration: 15.35 seconds
# Epoch 14/500, Train Loss: 2.2181, Train Acc: 0.1657, Val Loss: 2.2091, Val Acc: 0.1279
# Epoch Duration: 14.58 seconds
# Epoch 15/500, Train Loss: 2.2080, Train Acc: 0.2122, Val Loss: 2.2526, Val Acc: 0.1279
# Epoch Duration: 15.44 seconds
# Epoch 16/500, Train Loss: 2.1956, Train Acc: 0.1773, Val Loss: 2.2338, Val Acc: 0.1744
# Epoch Duration: 14.49 seconds
# Epoch 17/500, Train Loss: 2.1704, Train Acc: 0.2064, Val Loss: 2.2284, Val Acc: 0.1860
# Epoch Duration: 15.41 seconds
# Epoch 18/500, Train Loss: 2.1760, Train Acc: 0.2209, Val Loss: 2.2301, Val Acc: 0.1395
# Epoch Duration: 14.78 seconds
# Epoch 19/500, Train Loss: 2.1671, Train Acc: 0.1860, Val Loss: 2.2242, Val Acc: 0.1395
# Epoch Duration: 15.98 seconds
# Epoch 20/500, Train Loss: 2.1628, Train Acc: 0.2122, Val Loss: 2.2111, Val Acc: 0.1279
# Epoch Duration: 14.47 seconds
# Epoch 21/500, Train Loss: 2.1629, Train Acc: 0.1831, Val Loss: 2.1967, Val Acc: 0.1512
# Epoch Duration: 15.47 seconds
# Epoch 22/500, Train Loss: 2.1638, Train Acc: 0.2151, Val Loss: 2.2029, Val Acc: 0.1512
# Epoch Duration: 14.76 seconds
# Epoch 23/500, Train Loss: 2.1696, Train Acc: 0.2326, Val Loss: 2.2100, Val Acc: 0.1628
# Epoch Duration: 14.58 seconds
# Epoch 24/500, Train Loss: 2.1320, Train Acc: 0.2238, Val Loss: 2.1799, Val Acc: 0.1512
# Epoch Duration: 15.19 seconds
# Epoch 25/500, Train Loss: 2.1653, Train Acc: 0.2326, Val Loss: 2.1915, Val Acc: 0.1628
# Epoch Duration: 15.22 seconds
# Epoch 26/500, Train Loss: 2.1291, Train Acc: 0.2587, Val Loss: 2.2068, Val Acc: 0.1977
# Epoch Duration: 15.59 seconds
# Epoch 27/500, Train Loss: 2.1332, Train Acc: 0.2297, Val Loss: 2.1654, Val Acc: 0.1279
# Epoch Duration: 14.79 seconds
# Epoch 28/500, Train Loss: 2.1184, Train Acc: 0.2587, Val Loss: 2.1837, Val Acc: 0.1977
# Epoch Duration: 15.18 seconds
# Epoch 29/500, Train Loss: 2.1227, Train Acc: 0.2616, Val Loss: 2.1911, Val Acc: 0.1977
# Epoch Duration: 14.68 seconds
# Epoch 30/500, Train Loss: 2.1107, Train Acc: 0.2529, Val Loss: 2.1843, Val Acc: 0.1977
# Epoch Duration: 15.29 seconds
# Epoch 31/500, Train Loss: 2.1151, Train Acc: 0.2267, Val Loss: 2.1639, Val Acc: 0.1512
# Epoch Duration: 15.00 seconds
# Epoch 32/500, Train Loss: 2.1009, Train Acc: 0.2326, Val Loss: 2.1455, Val Acc: 0.1860
# Epoch Duration: 14.94 seconds
# Epoch 33/500, Train Loss: 2.0828, Train Acc: 0.2442, Val Loss: 2.1575, Val Acc: 0.1512
# Epoch Duration: 10.43 seconds
# Epoch 34/500, Train Loss: 2.0790, Train Acc: 0.2587, Val Loss: 2.1652, Val Acc: 0.1395
# Epoch Duration: 10.49 seconds
# Epoch 35/500, Train Loss: 2.0647, Train Acc: 0.2674, Val Loss: 2.2123, Val Acc: 0.1395
# Epoch Duration: 14.85 seconds
# Epoch 36/500, Train Loss: 2.0846, Train Acc: 0.2616, Val Loss: 2.1260, Val Acc: 0.1744
# Epoch Duration: 14.59 seconds
# Epoch 37/500, Train Loss: 2.0450, Train Acc: 0.2820, Val Loss: 2.1217, Val Acc: 0.2093
# Epoch Duration: 13.90 seconds
# Epoch 38/500, Train Loss: 2.0225, Train Acc: 0.2703, Val Loss: 2.1693, Val Acc: 0.1512
# Epoch Duration: 10.45 seconds
# Epoch 39/500, Train Loss: 2.0360, Train Acc: 0.2733, Val Loss: 2.1011, Val Acc: 0.1860
# Epoch Duration: 10.55 seconds
# Epoch 40/500, Train Loss: 2.0176, Train Acc: 0.3052, Val Loss: 2.1461, Val Acc: 0.1744
# Epoch Duration: 12.74 seconds
# Epoch 41/500, Train Loss: 1.9979, Train Acc: 0.3081, Val Loss: 2.1615, Val Acc: 0.2442
# Epoch Duration: 10.63 seconds
# Epoch 42/500, Train Loss: 2.0194, Train Acc: 0.3052, Val Loss: 2.0707, Val Acc: 0.1977
# Epoch Duration: 12.52 seconds
# Epoch 43/500, Train Loss: 1.9761, Train Acc: 0.3285, Val Loss: 2.1006, Val Acc: 0.2093
# Epoch Duration: 10.79 seconds
# Epoch 44/500, Train Loss: 1.9959, Train Acc: 0.2965, Val Loss: 2.1147, Val Acc: 0.2093
# Epoch Duration: 10.57 seconds
# Epoch 45/500, Train Loss: 1.9536, Train Acc: 0.3314, Val Loss: 2.0261, Val Acc: 0.2209
# Epoch Duration: 13.58 seconds
# Epoch 46/500, Train Loss: 1.9596, Train Acc: 0.3314, Val Loss: 2.0390, Val Acc: 0.3023
# Epoch Duration: 10.69 seconds
# Epoch 47/500, Train Loss: 1.9249, Train Acc: 0.3430, Val Loss: 2.0203, Val Acc: 0.2907
# Epoch Duration: 10.57 seconds
# Epoch 48/500, Train Loss: 1.9202, Train Acc: 0.3285, Val Loss: 2.0161, Val Acc: 0.2558
# Epoch Duration: 15.69 seconds
# Epoch 49/500, Train Loss: 1.8936, Train Acc: 0.3663, Val Loss: 2.0343, Val Acc: 0.2442
# Epoch Duration: 13.99 seconds
# Epoch 50/500, Train Loss: 1.8626, Train Acc: 0.3953, Val Loss: 2.0240, Val Acc: 0.2791
# Epoch Duration: 11.36 seconds
# Epoch 51/500, Train Loss: 1.8587, Train Acc: 0.3808, Val Loss: 1.9391, Val Acc: 0.3140
# Epoch Duration: 10.74 seconds
# Epoch 52/500, Train Loss: 1.8250, Train Acc: 0.4012, Val Loss: 2.0198, Val Acc: 0.2791
# Epoch Duration: 14.25 seconds
# Epoch 53/500, Train Loss: 1.8286, Train Acc: 0.3866, Val Loss: 2.0651, Val Acc: 0.2326
# Epoch Duration: 11.40 seconds
# Epoch 54/500, Train Loss: 1.7988, Train Acc: 0.3924, Val Loss: 2.0266, Val Acc: 0.2442
# Epoch Duration: 10.66 seconds
# Epoch 55/500, Train Loss: 1.7962, Train Acc: 0.4302, Val Loss: 1.9250, Val Acc: 0.2674
# Epoch Duration: 15.71 seconds
# Epoch 56/500, Train Loss: 1.7718, Train Acc: 0.3837, Val Loss: 2.1568, Val Acc: 0.1860
# Epoch Duration: 15.17 seconds
# Epoch 57/500, Train Loss: 1.7662, Train Acc: 0.3663, Val Loss: 1.9531, Val Acc: 0.2209
# Epoch Duration: 15.63 seconds
# Epoch 58/500, Train Loss: 1.7479, Train Acc: 0.4157, Val Loss: 1.9846, Val Acc: 0.2907
# Epoch Duration: 14.75 seconds
# Epoch 59/500, Train Loss: 1.7051, Train Acc: 0.4360, Val Loss: 1.8573, Val Acc: 0.3023
# Epoch Duration: 15.71 seconds
# Epoch 60/500, Train Loss: 1.6581, Train Acc: 0.4390, Val Loss: 1.8492, Val Acc: 0.3023
# Epoch Duration: 14.94 seconds
# Epoch 61/500, Train Loss: 1.7059, Train Acc: 0.4477, Val Loss: 1.7918, Val Acc: 0.3605
# Epoch Duration: 14.72 seconds
# Epoch 62/500, Train Loss: 1.6812, Train Acc: 0.4913, Val Loss: 1.7554, Val Acc: 0.3721
# Epoch Duration: 15.44 seconds
# Epoch 63/500, Train Loss: 1.6580, Train Acc: 0.4419, Val Loss: 1.7718, Val Acc: 0.3721
# Epoch Duration: 14.78 seconds
# Epoch 64/500, Train Loss: 1.6164, Train Acc: 0.5233, Val Loss: 1.7592, Val Acc: 0.3837
# Epoch Duration: 15.49 seconds
# Epoch 65/500, Train Loss: 1.6008, Train Acc: 0.5174, Val Loss: 1.6624, Val Acc: 0.4070
# Epoch Duration: 14.77 seconds
# Epoch 66/500, Train Loss: 1.5692, Train Acc: 0.5349, Val Loss: 1.7241, Val Acc: 0.3372
# Epoch Duration: 15.41 seconds
# Epoch 67/500, Train Loss: 1.5421, Train Acc: 0.5523, Val Loss: 1.7647, Val Acc: 0.3372
# Epoch Duration: 14.61 seconds
# Epoch 68/500, Train Loss: 1.4879, Train Acc: 0.5610, Val Loss: 1.7698, Val Acc: 0.3837
# Epoch Duration: 15.25 seconds
# Epoch 69/500, Train Loss: 1.5336, Train Acc: 0.5494, Val Loss: 1.7781, Val Acc: 0.3023
# Epoch Duration: 14.63 seconds
# Epoch 70/500, Train Loss: 1.4967, Train Acc: 0.5552, Val Loss: 1.6144, Val Acc: 0.3256
# Epoch Duration: 15.33 seconds
# Epoch 71/500, Train Loss: 1.4775, Train Acc: 0.5233, Val Loss: 1.6097, Val Acc: 0.4535
# Epoch Duration: 14.75 seconds
# Epoch 72/500, Train Loss: 1.4694, Train Acc: 0.5610, Val Loss: 1.5222, Val Acc: 0.5000
# Epoch Duration: 15.42 seconds
# Epoch 73/500, Train Loss: 1.4299, Train Acc: 0.6105, Val Loss: 1.6222, Val Acc: 0.3953
# Epoch Duration: 14.52 seconds
# Epoch 74/500, Train Loss: 1.4538, Train Acc: 0.5610, Val Loss: 1.5693, Val Acc: 0.4884
# Epoch Duration: 15.16 seconds
# Epoch 75/500, Train Loss: 1.4054, Train Acc: 0.5930, Val Loss: 1.6357, Val Acc: 0.3953
# Epoch Duration: 14.58 seconds
# Epoch 76/500, Train Loss: 1.3318, Train Acc: 0.6105, Val Loss: 1.6182, Val Acc: 0.4186
# Epoch Duration: 15.34 seconds
# Epoch 77/500, Train Loss: 1.3834, Train Acc: 0.5698, Val Loss: 1.5105, Val Acc: 0.4535
# Epoch Duration: 14.69 seconds
# Epoch 78/500, Train Loss: 1.3426, Train Acc: 0.6134, Val Loss: 1.5590, Val Acc: 0.3953
# Epoch Duration: 14.54 seconds
# Epoch 79/500, Train Loss: 1.3033, Train Acc: 0.5872, Val Loss: 1.6238, Val Acc: 0.4535
# Epoch Duration: 15.12 seconds
# Epoch 80/500, Train Loss: 1.2967, Train Acc: 0.6105, Val Loss: 1.5507, Val Acc: 0.4651
# Epoch Duration: 14.76 seconds
# Epoch 81/500, Train Loss: 1.2338, Train Acc: 0.6628, Val Loss: 1.4926, Val Acc: 0.5000
# Epoch Duration: 15.06 seconds
# Epoch 82/500, Train Loss: 1.2482, Train Acc: 0.6453, Val Loss: 1.3755, Val Acc: 0.5116
# Epoch Duration: 14.36 seconds
# Epoch 83/500, Train Loss: 1.2300, Train Acc: 0.5959, Val Loss: 1.4751, Val Acc: 0.5000
# Epoch Duration: 15.30 seconds
# Epoch 84/500, Train Loss: 1.2077, Train Acc: 0.6628, Val Loss: 1.3411, Val Acc: 0.5465
# Epoch Duration: 14.74 seconds
# Epoch 85/500, Train Loss: 1.1989, Train Acc: 0.6715, Val Loss: 1.3370, Val Acc: 0.4767
# Epoch Duration: 15.30 seconds
# Epoch 86/500, Train Loss: 1.1355, Train Acc: 0.6860, Val Loss: 1.4739, Val Acc: 0.4884
# Epoch Duration: 14.98 seconds
# Epoch 87/500, Train Loss: 1.1741, Train Acc: 0.6453, Val Loss: 1.6185, Val Acc: 0.4535
# Epoch Duration: 15.32 seconds
# Epoch 88/500, Train Loss: 1.1304, Train Acc: 0.6686, Val Loss: 1.4721, Val Acc: 0.5000
# Epoch Duration: 15.29 seconds
# Epoch 89/500, Train Loss: 1.1346, Train Acc: 0.6686, Val Loss: 1.4578, Val Acc: 0.4651
# Epoch Duration: 15.19 seconds
# Epoch 90/500, Train Loss: 1.0317, Train Acc: 0.7035, Val Loss: 1.3290, Val Acc: 0.4767
# Epoch Duration: 14.36 seconds
# Epoch 91/500, Train Loss: 1.0309, Train Acc: 0.7035, Val Loss: 1.3992, Val Acc: 0.4419
# Epoch Duration: 15.16 seconds
# Epoch 92/500, Train Loss: 1.0560, Train Acc: 0.7006, Val Loss: 1.4286, Val Acc: 0.4884
# Epoch Duration: 14.49 seconds
# Epoch 93/500, Train Loss: 1.0056, Train Acc: 0.7122, Val Loss: 1.3939, Val Acc: 0.4302
# Epoch Duration: 15.11 seconds
# Epoch 94/500, Train Loss: 1.0486, Train Acc: 0.7151, Val Loss: 1.2885, Val Acc: 0.5698
# Epoch Duration: 14.49 seconds
# Epoch 95/500, Train Loss: 1.0151, Train Acc: 0.7267, Val Loss: 1.3286, Val Acc: 0.5465
# Epoch Duration: 14.72 seconds
# Epoch 96/500, Train Loss: 0.9689, Train Acc: 0.7267, Val Loss: 1.2066, Val Acc: 0.5116
# Epoch Duration: 15.28 seconds
# Epoch 97/500, Train Loss: 0.9756, Train Acc: 0.7122, Val Loss: 1.3176, Val Acc: 0.6163
# Epoch Duration: 14.36 seconds
# Epoch 98/500, Train Loss: 0.9349, Train Acc: 0.7645, Val Loss: 1.2608, Val Acc: 0.5698
# Epoch Duration: 16.55 seconds
# Epoch 99/500, Train Loss: 0.9083, Train Acc: 0.7326, Val Loss: 1.2300, Val Acc: 0.5581
# Epoch Duration: 9.47 seconds
# Epoch 100/500, Train Loss: 0.9369, Train Acc: 0.7529, Val Loss: 1.1544, Val Acc: 0.5698
# Epoch Duration: 9.84 seconds
# Epoch 101/500, Train Loss: 0.8770, Train Acc: 0.7703, Val Loss: 1.1918, Val Acc: 0.6047
# Epoch Duration: 12.09 seconds
# Epoch 102/500, Train Loss: 0.9033, Train Acc: 0.7703, Val Loss: 1.2962, Val Acc: 0.5465
# Epoch Duration: 14.89 seconds
# Epoch 103/500, Train Loss: 0.8668, Train Acc: 0.7762, Val Loss: 1.3234, Val Acc: 0.5349
# Epoch Duration: 15.61 seconds
# Epoch 104/500, Train Loss: 0.8924, Train Acc: 0.7151, Val Loss: 1.2960, Val Acc: 0.4651
# Epoch Duration: 14.79 seconds
# Epoch 105/500, Train Loss: 0.8815, Train Acc: 0.6831, Val Loss: 1.0720, Val Acc: 0.6279
# Epoch Duration: 15.52 seconds
# Epoch 106/500, Train Loss: 0.8835, Train Acc: 0.7587, Val Loss: 1.0199, Val Acc: 0.5930
# Epoch Duration: 14.53 seconds
# Epoch 107/500, Train Loss: 0.8205, Train Acc: 0.7645, Val Loss: 1.1473, Val Acc: 0.6628
# Epoch Duration: 15.32 seconds
# Epoch 108/500, Train Loss: 0.8245, Train Acc: 0.7587, Val Loss: 1.0850, Val Acc: 0.6163
# Epoch Duration: 14.49 seconds
# Epoch 109/500, Train Loss: 0.7725, Train Acc: 0.7791, Val Loss: 1.1600, Val Acc: 0.6047
# Epoch Duration: 15.36 seconds
# Epoch 110/500, Train Loss: 0.7547, Train Acc: 0.7703, Val Loss: 1.2016, Val Acc: 0.6279
# Epoch Duration: 14.43 seconds
# Epoch 111/500, Train Loss: 0.7372, Train Acc: 0.7733, Val Loss: 1.1049, Val Acc: 0.5930
# Epoch Duration: 15.69 seconds
# Epoch 112/500, Train Loss: 0.7964, Train Acc: 0.7733, Val Loss: 1.2635, Val Acc: 0.5233
# Epoch Duration: 14.88 seconds
# Epoch 113/500, Train Loss: 0.7033, Train Acc: 0.8198, Val Loss: 1.3970, Val Acc: 0.5000
# Epoch Duration: 15.26 seconds
# Epoch 114/500, Train Loss: 0.7435, Train Acc: 0.8285, Val Loss: 1.1248, Val Acc: 0.6279
# Epoch Duration: 14.57 seconds
# Epoch 115/500, Train Loss: 0.6759, Train Acc: 0.8023, Val Loss: 0.9733, Val Acc: 0.6512
# Epoch Duration: 15.26 seconds
# Epoch 116/500, Train Loss: 0.6556, Train Acc: 0.8110, Val Loss: 1.0229, Val Acc: 0.6047
# Epoch Duration: 14.51 seconds
# Epoch 117/500, Train Loss: 0.6787, Train Acc: 0.7965, Val Loss: 1.1530, Val Acc: 0.5698
# Epoch Duration: 14.44 seconds
# Epoch 118/500, Train Loss: 0.7026, Train Acc: 0.7878, Val Loss: 1.0668, Val Acc: 0.6163
# Epoch Duration: 15.18 seconds
# Epoch 119/500, Train Loss: 0.6089, Train Acc: 0.8488, Val Loss: 1.1942, Val Acc: 0.5930
# Epoch Duration: 14.29 seconds
# Epoch 120/500, Train Loss: 0.7113, Train Acc: 0.8023, Val Loss: 1.0050, Val Acc: 0.6279
# Epoch Duration: 15.21 seconds
# Epoch 121/500, Train Loss: 0.6566, Train Acc: 0.8343, Val Loss: 0.9611, Val Acc: 0.6744
# Epoch Duration: 15.21 seconds
# Epoch 122/500, Train Loss: 0.6717, Train Acc: 0.7645, Val Loss: 1.1852, Val Acc: 0.6163
# Epoch Duration: 15.39 seconds
# Epoch 123/500, Train Loss: 0.6407, Train Acc: 0.8198, Val Loss: 0.9147, Val Acc: 0.6860
# Epoch Duration: 14.55 seconds
# Epoch 124/500, Train Loss: 0.6440, Train Acc: 0.8052, Val Loss: 1.1036, Val Acc: 0.6047
# Epoch Duration: 14.51 seconds
# Epoch 125/500, Train Loss: 0.5789, Train Acc: 0.8314, Val Loss: 1.1575, Val Acc: 0.6279
# Epoch Duration: 9.46 seconds
# Epoch 126/500, Train Loss: 0.5959, Train Acc: 0.8314, Val Loss: 1.1457, Val Acc: 0.6628
# Epoch Duration: 9.21 seconds
# Epoch 127/500, Train Loss: 0.6084, Train Acc: 0.8401, Val Loss: 1.0120, Val Acc: 0.7093
# Epoch Duration: 12.40 seconds
# Epoch 128/500, Train Loss: 0.6061, Train Acc: 0.8372, Val Loss: 0.9601, Val Acc: 0.7093
# Epoch Duration: 14.98 seconds
# Epoch 129/500, Train Loss: 0.6065, Train Acc: 0.8110, Val Loss: 1.0191, Val Acc: 0.6279
# Epoch Duration: 16.16 seconds
# Epoch 130/500, Train Loss: 0.5875, Train Acc: 0.8459, Val Loss: 1.1604, Val Acc: 0.6395
# Epoch Duration: 14.71 seconds
# Epoch 131/500, Train Loss: 0.6052, Train Acc: 0.8140, Val Loss: 0.9088, Val Acc: 0.7093
# Epoch Duration: 15.30 seconds
# Epoch 132/500, Train Loss: 0.5783, Train Acc: 0.8517, Val Loss: 0.9764, Val Acc: 0.7209
# Epoch Duration: 14.49 seconds
# Epoch 133/500, Train Loss: 0.5517, Train Acc: 0.8547, Val Loss: 1.0679, Val Acc: 0.6395
# Epoch Duration: 14.75 seconds
# Epoch 134/500, Train Loss: 0.5236, Train Acc: 0.8692, Val Loss: 0.8800, Val Acc: 0.6860
# Epoch Duration: 9.40 seconds
# Epoch 135/500, Train Loss: 0.5283, Train Acc: 0.8401, Val Loss: 0.9074, Val Acc: 0.6395
# Epoch Duration: 9.44 seconds
# Epoch 136/500, Train Loss: 0.5665, Train Acc: 0.8343, Val Loss: 0.8676, Val Acc: 0.7326
# Epoch Duration: 11.65 seconds
# Epoch 137/500, Train Loss: 0.5165, Train Acc: 0.8663, Val Loss: 1.0345, Val Acc: 0.6744
# Epoch Duration: 9.65 seconds
# Epoch 138/500, Train Loss: 0.5300, Train Acc: 0.8372, Val Loss: 0.8928, Val Acc: 0.6860
# Epoch Duration: 9.77 seconds
# Epoch 139/500, Train Loss: 0.5323, Train Acc: 0.8547, Val Loss: 0.9703, Val Acc: 0.6279
# Epoch Duration: 11.80 seconds
# Epoch 140/500, Train Loss: 0.5033, Train Acc: 0.8576, Val Loss: 1.0997, Val Acc: 0.6512
# Epoch Duration: 9.52 seconds
# Epoch 141/500, Train Loss: 0.4288, Train Acc: 0.9099, Val Loss: 1.0762, Val Acc: 0.6512
# Epoch Duration: 11.37 seconds
# Epoch 142/500, Train Loss: 0.4761, Train Acc: 0.8605, Val Loss: 0.9023, Val Acc: 0.6977
# Epoch Duration: 16.17 seconds
# Epoch 143/500, Train Loss: 0.4650, Train Acc: 0.8430, Val Loss: 0.8462, Val Acc: 0.7093
# Epoch Duration: 13.44 seconds
# Epoch 144/500, Train Loss: 0.4385, Train Acc: 0.8721, Val Loss: 0.7854, Val Acc: 0.7442
# Epoch Duration: 10.77 seconds
# Epoch 145/500, Train Loss: 0.4647, Train Acc: 0.8750, Val Loss: 0.9249, Val Acc: 0.7558
# Epoch Duration: 10.92 seconds
# Epoch 146/500, Train Loss: 0.4730, Train Acc: 0.8692, Val Loss: 0.7202, Val Acc: 0.7674
# Epoch Duration: 15.10 seconds
# Epoch 147/500, Train Loss: 0.4500, Train Acc: 0.8866, Val Loss: 1.0040, Val Acc: 0.6279
# Epoch Duration: 15.74 seconds
# Epoch 148/500, Train Loss: 0.4409, Train Acc: 0.8779, Val Loss: 0.8004, Val Acc: 0.7326
# Epoch Duration: 15.00 seconds
# Epoch 149/500, Train Loss: 0.4637, Train Acc: 0.8983, Val Loss: 0.7744, Val Acc: 0.7093
# Epoch Duration: 15.78 seconds
# Epoch 150/500, Train Loss: 0.4332, Train Acc: 0.8837, Val Loss: 0.9240, Val Acc: 0.7326
# Epoch Duration: 14.85 seconds
# Epoch 151/500, Train Loss: 0.4579, Train Acc: 0.8663, Val Loss: 0.9361, Val Acc: 0.7093
# Epoch Duration: 15.63 seconds
# Epoch 152/500, Train Loss: 0.3793, Train Acc: 0.9099, Val Loss: 0.9829, Val Acc: 0.6395
# Epoch Duration: 14.70 seconds
# Epoch 153/500, Train Loss: 0.4340, Train Acc: 0.8692, Val Loss: 0.8165, Val Acc: 0.7209
# Epoch Duration: 15.40 seconds
# Epoch 154/500, Train Loss: 0.4469, Train Acc: 0.8866, Val Loss: 1.0058, Val Acc: 0.7326
# Epoch Duration: 14.61 seconds
# Epoch 155/500, Train Loss: 0.3755, Train Acc: 0.8895, Val Loss: 0.8863, Val Acc: 0.7442
# Epoch Duration: 15.44 seconds
# Epoch 156/500, Train Loss: 0.4112, Train Acc: 0.8837, Val Loss: 0.7696, Val Acc: 0.7558
# Epoch Duration: 14.69 seconds
# Epoch 157/500, Train Loss: 0.4299, Train Acc: 0.8953, Val Loss: 0.7477, Val Acc: 0.7791
# Epoch Duration: 15.30 seconds
# Epoch 158/500, Train Loss: 0.3843, Train Acc: 0.9099, Val Loss: 0.8634, Val Acc: 0.7209
# Epoch Duration: 14.55 seconds
# Epoch 159/500, Train Loss: 0.3625, Train Acc: 0.9012, Val Loss: 1.0293, Val Acc: 0.6860
# Epoch Duration: 14.79 seconds
# Epoch 160/500, Train Loss: 0.3466, Train Acc: 0.9041, Val Loss: 0.7614, Val Acc: 0.7093
# Epoch Duration: 14.95 seconds
# Epoch 161/500, Train Loss: 0.3267, Train Acc: 0.9099, Val Loss: 0.8011, Val Acc: 0.7442
# Epoch Duration: 14.44 seconds
# Epoch 162/500, Train Loss: 0.3340, Train Acc: 0.9041, Val Loss: 0.8634, Val Acc: 0.7209
# Epoch Duration: 11.26 seconds
# Epoch 163/500, Train Loss: 0.3693, Train Acc: 0.8837, Val Loss: 0.6022, Val Acc: 0.8023
# Epoch Duration: 10.53 seconds
# Epoch 164/500, Train Loss: 0.3418, Train Acc: 0.8983, Val Loss: 0.8464, Val Acc: 0.6977
# Epoch Duration: 14.89 seconds
# Epoch 165/500, Train Loss: 0.3433, Train Acc: 0.9012, Val Loss: 0.6532, Val Acc: 0.7326
# Epoch Duration: 14.90 seconds
# Epoch 166/500, Train Loss: 0.3281, Train Acc: 0.9070, Val Loss: 0.8040, Val Acc: 0.6744
# Epoch Duration: 14.45 seconds
# Epoch 167/500, Train Loss: 0.3976, Train Acc: 0.8750, Val Loss: 0.7884, Val Acc: 0.7326
# Epoch Duration: 10.57 seconds
# Epoch 168/500, Train Loss: 0.4206, Train Acc: 0.8924, Val Loss: 0.6184, Val Acc: 0.7442
# Epoch Duration: 10.48 seconds
# Epoch 169/500, Train Loss: 0.3054, Train Acc: 0.9273, Val Loss: 0.7787, Val Acc: 0.7209
# Epoch Duration: 12.18 seconds
# Epoch 170/500, Train Loss: 0.3178, Train Acc: 0.9070, Val Loss: 0.9951, Val Acc: 0.6744
# Epoch Duration: 10.68 seconds
# Epoch 171/500, Train Loss: 0.3532, Train Acc: 0.9012, Val Loss: 0.9868, Val Acc: 0.7442
# Epoch Duration: 10.66 seconds
# Epoch 172/500, Train Loss: 0.3627, Train Acc: 0.8924, Val Loss: 0.7635, Val Acc: 0.7209
# Epoch Duration: 15.58 seconds
# Epoch 173/500, Train Loss: 0.3760, Train Acc: 0.8983, Val Loss: 0.7745, Val Acc: 0.7674
# Epoch Duration: 15.02 seconds
# Epoch 174/500, Train Loss: 0.3520, Train Acc: 0.8953, Val Loss: 0.9523, Val Acc: 0.6977
# Epoch Duration: 15.56 seconds
# Epoch 175/500, Train Loss: 0.3265, Train Acc: 0.9157, Val Loss: 0.9051, Val Acc: 0.7093
# Epoch Duration: 14.71 seconds
# Epoch 176/500, Train Loss: 0.3417, Train Acc: 0.9186, Val Loss: 0.7575, Val Acc: 0.7326
# Epoch Duration: 15.50 seconds
# Epoch 177/500, Train Loss: 0.3435, Train Acc: 0.9186, Val Loss: 0.7355, Val Acc: 0.7674
# Epoch Duration: 14.67 seconds
# Epoch 178/500, Train Loss: 0.3492, Train Acc: 0.8895, Val Loss: 0.7800, Val Acc: 0.6860
# Epoch Duration: 15.53 seconds
# Epoch 179/500, Train Loss: 0.2817, Train Acc: 0.9099, Val Loss: 0.7911, Val Acc: 0.6977
# Epoch Duration: 14.50 seconds
# Epoch 180/500, Train Loss: 0.2692, Train Acc: 0.9390, Val Loss: 0.7883, Val Acc: 0.7326
# Epoch Duration: 15.27 seconds
# Epoch 181/500, Train Loss: 0.3286, Train Acc: 0.9012, Val Loss: 0.7776, Val Acc: 0.7093
# Epoch Duration: 14.52 seconds
# Epoch 182/500, Train Loss: 0.3288, Train Acc: 0.9273, Val Loss: 0.8468, Val Acc: 0.7442
# Epoch Duration: 14.89 seconds
# Epoch 183/500, Train Loss: 0.2788, Train Acc: 0.9273, Val Loss: 0.8697, Val Acc: 0.7209
# Epoch Duration: 15.00 seconds
# Epoch 184/500, Train Loss: 0.3238, Train Acc: 0.9099, Val Loss: 0.9869, Val Acc: 0.7209
# Epoch Duration: 14.43 seconds
# Epoch 185/500, Train Loss: 0.3286, Train Acc: 0.8895, Val Loss: 0.8532, Val Acc: 0.7442
# Epoch Duration: 15.23 seconds
# Epoch 186/500, Train Loss: 0.2792, Train Acc: 0.9128, Val Loss: 0.9517, Val Acc: 0.6744
# Epoch Duration: 14.46 seconds
# Epoch 187/500, Train Loss: 0.2686, Train Acc: 0.9099, Val Loss: 0.9665, Val Acc: 0.6512
# Epoch Duration: 15.02 seconds
# Epoch 188/500, Train Loss: 0.2724, Train Acc: 0.9186, Val Loss: 0.9275, Val Acc: 0.7093
# Epoch Duration: 10.51 seconds
# Epoch 189/500, Train Loss: 0.2233, Train Acc: 0.9360, Val Loss: 0.6913, Val Acc: 0.7674
# Epoch Duration: 11.01 seconds
# Epoch 190/500, Train Loss: 0.2203, Train Acc: 0.9273, Val Loss: 0.8938, Val Acc: 0.7093
# Epoch Duration: 13.78 seconds
# Epoch 191/500, Train Loss: 0.2504, Train Acc: 0.9186, Val Loss: 0.8728, Val Acc: 0.7326
# Epoch Duration: 14.93 seconds
# Epoch 192/500, Train Loss: 0.2537, Train Acc: 0.9244, Val Loss: 0.7988, Val Acc: 0.7326
# Epoch Duration: 14.88 seconds
# Epoch 193/500, Train Loss: 0.3024, Train Acc: 0.9128, Val Loss: 0.9472, Val Acc: 0.6744
# Epoch Duration: 10.53 seconds
# Epoch 194/500, Train Loss: 0.2643, Train Acc: 0.9302, Val Loss: 1.0384, Val Acc: 0.7093
# Epoch Duration: 11.20 seconds
# Epoch 195/500, Train Loss: 0.2881, Train Acc: 0.9302, Val Loss: 0.7620, Val Acc: 0.7791
# Epoch Duration: 14.43 seconds
# Epoch 196/500, Train Loss: 0.2489, Train Acc: 0.9331, Val Loss: 0.8266, Val Acc: 0.7209
# Epoch Duration: 15.60 seconds
# Epoch 197/500, Train Loss: 0.2724, Train Acc: 0.9244, Val Loss: 0.8445, Val Acc: 0.7093
# Epoch Duration: 15.10 seconds
# Epoch 198/500, Train Loss: 0.2730, Train Acc: 0.9331, Val Loss: 0.6538, Val Acc: 0.7791
# Epoch Duration: 15.43 seconds
# Epoch 199/500, Train Loss: 0.2815, Train Acc: 0.9157, Val Loss: 0.8573, Val Acc: 0.7209
# Epoch Duration: 14.92 seconds
# Epoch 200/500, Train Loss: 0.2412, Train Acc: 0.9448, Val Loss: 0.8690, Val Acc: 0.7907
# Epoch Duration: 14.69 seconds
# Epoch 201/500, Train Loss: 0.3080, Train Acc: 0.9273, Val Loss: 0.7713, Val Acc: 0.7326
# Epoch Duration: 15.32 seconds
# Epoch 202/500, Train Loss: 0.3156, Train Acc: 0.9070, Val Loss: 0.8641, Val Acc: 0.6977
# Epoch Duration: 14.38 seconds
# Epoch 203/500, Train Loss: 0.2966, Train Acc: 0.9273, Val Loss: 0.8903, Val Acc: 0.7442
# Epoch Duration: 15.23 seconds
# Epoch 204/500, Train Loss: 0.2500, Train Acc: 0.9215, Val Loss: 0.8411, Val Acc: 0.7326
# Epoch Duration: 14.49 seconds
# Epoch 205/500, Train Loss: 0.3087, Train Acc: 0.9012, Val Loss: 0.7929, Val Acc: 0.7442
# Epoch Duration: 12.83 seconds
# Epoch 206/500, Train Loss: 0.2558, Train Acc: 0.9331, Val Loss: 0.7667, Val Acc: 0.7442
# Epoch Duration: 10.31 seconds
# Epoch 207/500, Train Loss: 0.2894, Train Acc: 0.9244, Val Loss: 1.0464, Val Acc: 0.6744
# Epoch Duration: 11.59 seconds
# Epoch 208/500, Train Loss: 0.2623, Train Acc: 0.9215, Val Loss: 0.8403, Val Acc: 0.7209
# Epoch Duration: 14.55 seconds
# Epoch 209/500, Train Loss: 0.2922, Train Acc: 0.9331, Val Loss: 0.8917, Val Acc: 0.7442
# Epoch Duration: 14.82 seconds
# Epoch 210/500, Train Loss: 0.2813, Train Acc: 0.9215, Val Loss: 0.7906, Val Acc: 0.7674
# Epoch Duration: 15.78 seconds
# Epoch 211/500, Train Loss: 0.2426, Train Acc: 0.9419, Val Loss: 0.8387, Val Acc: 0.7326
# Epoch Duration: 14.52 seconds
# Epoch 212/500, Train Loss: 0.2253, Train Acc: 0.9390, Val Loss: 0.8178, Val Acc: 0.7558
# Epoch Duration: 15.49 seconds
# Epoch 213/500, Train Loss: 0.2948, Train Acc: 0.9186, Val Loss: 0.7512, Val Acc: 0.7326
# Epoch Duration: 14.19 seconds
# Epoch 214/500, Train Loss: 0.2574, Train Acc: 0.9331, Val Loss: 0.7418, Val Acc: 0.7326
# Epoch Duration: 11.08 seconds
# Epoch 215/500, Train Loss: 0.2372, Train Acc: 0.9360, Val Loss: 0.8047, Val Acc: 0.6977
# Epoch Duration: 10.62 seconds
# Epoch 216/500, Train Loss: 0.2372, Train Acc: 0.9302, Val Loss: 0.7845, Val Acc: 0.6977
# Epoch Duration: 13.60 seconds
# Epoch 217/500, Train Loss: 0.2450, Train Acc: 0.9186, Val Loss: 0.8565, Val Acc: 0.6977
# Epoch Duration: 15.74 seconds
# Epoch 218/500, Train Loss: 0.2645, Train Acc: 0.9244, Val Loss: 1.0548, Val Acc: 0.6744
# Epoch Duration: 14.16 seconds
# Epoch 219/500, Train Loss: 0.2976, Train Acc: 0.9099, Val Loss: 0.7498, Val Acc: 0.7326
# Epoch Duration: 11.18 seconds
# Epoch 220/500, Train Loss: 0.2333, Train Acc: 0.9477, Val Loss: 0.6179, Val Acc: 0.8023
# Epoch Duration: 10.61 seconds
# Epoch 221/500, Train Loss: 0.1931, Train Acc: 0.9448, Val Loss: 0.8684, Val Acc: 0.7558
# Epoch Duration: 14.25 seconds
# Epoch 222/500, Train Loss: 0.1959, Train Acc: 0.9622, Val Loss: 0.7608, Val Acc: 0.7442
# Epoch Duration: 15.48 seconds
# Epoch 223/500, Train Loss: 0.2065, Train Acc: 0.9564, Val Loss: 0.8487, Val Acc: 0.7093
# Epoch Duration: 14.72 seconds
# Epoch 224/500, Train Loss: 0.2176, Train Acc: 0.9448, Val Loss: 0.6999, Val Acc: 0.7791
# Epoch Duration: 15.18 seconds
# Epoch 225/500, Train Loss: 0.2154, Train Acc: 0.9360, Val Loss: 0.7331, Val Acc: 0.7442
# Epoch Duration: 16.31 seconds
# Epoch 226/500, Train Loss: 0.2205, Train Acc: 0.9477, Val Loss: 0.7990, Val Acc: 0.7558
# Epoch Duration: 15.69 seconds
# Epoch 227/500, Train Loss: 0.2701, Train Acc: 0.9186, Val Loss: 1.0110, Val Acc: 0.6977
# Epoch Duration: 14.50 seconds
# Epoch 228/500, Train Loss: 0.1880, Train Acc: 0.9651, Val Loss: 0.9610, Val Acc: 0.6860
# Epoch Duration: 15.03 seconds
# Epoch 229/500, Train Loss: 0.2054, Train Acc: 0.9419, Val Loss: 0.8549, Val Acc: 0.7558
# Epoch Duration: 14.52 seconds
# Epoch 230/500, Train Loss: 0.1911, Train Acc: 0.9506, Val Loss: 0.7432, Val Acc: 0.7791
# Epoch Duration: 15.55 seconds
# Epoch 231/500, Train Loss: 0.2222, Train Acc: 0.9157, Val Loss: 0.6481, Val Acc: 0.7093
# Epoch Duration: 14.55 seconds
# Epoch 232/500, Train Loss: 0.2080, Train Acc: 0.9302, Val Loss: 1.0152, Val Acc: 0.6977
# Epoch Duration: 15.19 seconds
# Epoch 233/500, Train Loss: 0.1758, Train Acc: 0.9477, Val Loss: 0.8276, Val Acc: 0.7442
# Epoch Duration: 14.49 seconds
# Epoch 234/500, Train Loss: 0.2244, Train Acc: 0.9477, Val Loss: 0.6916, Val Acc: 0.7674
# Epoch Duration: 15.31 seconds
# Epoch 235/500, Train Loss: 0.2158, Train Acc: 0.9273, Val Loss: 0.7886, Val Acc: 0.7326
# Epoch Duration: 14.47 seconds
# Epoch 236/500, Train Loss: 0.1762, Train Acc: 0.9360, Val Loss: 0.8908, Val Acc: 0.7326
# Epoch Duration: 15.32 seconds
# Epoch 237/500, Train Loss: 0.1694, Train Acc: 0.9477, Val Loss: 0.7615, Val Acc: 0.7442
# Epoch Duration: 14.54 seconds
# Epoch 238/500, Train Loss: 0.2136, Train Acc: 0.9390, Val Loss: 0.8334, Val Acc: 0.7442
# Epoch Duration: 14.57 seconds
# Epoch 239/500, Train Loss: 0.2051, Train Acc: 0.9244, Val Loss: 0.6952, Val Acc: 0.7209
# Epoch Duration: 18.97 seconds
# Epoch 240/500, Train Loss: 0.1980, Train Acc: 0.9448, Val Loss: 0.6500, Val Acc: 0.7442
# Epoch Duration: 10.68 seconds
# Epoch 241/500, Train Loss: 0.1553, Train Acc: 0.9680, Val Loss: 0.7673, Val Acc: 0.7558
# Epoch Duration: 11.11 seconds
# Epoch 242/500, Train Loss: 0.1984, Train Acc: 0.9360, Val Loss: 0.7212, Val Acc: 0.7209
# Epoch Duration: 13.49 seconds
# Epoch 243/500, Train Loss: 0.2154, Train Acc: 0.9477, Val Loss: 0.5920, Val Acc: 0.7558
# Epoch Duration: 14.42 seconds
# Epoch 244/500, Train Loss: 0.2285, Train Acc: 0.9390, Val Loss: 0.7542, Val Acc: 0.8023
# Epoch Duration: 10.51 seconds
# Epoch 245/500, Train Loss: 0.1903, Train Acc: 0.9651, Val Loss: 0.8753, Val Acc: 0.7326
# Epoch Duration: 10.68 seconds
# Epoch 246/500, Train Loss: 0.2194, Train Acc: 0.9331, Val Loss: 0.7940, Val Acc: 0.7558
# Epoch Duration: 14.36 seconds
# Epoch 247/500, Train Loss: 0.2402, Train Acc: 0.9390, Val Loss: 0.7656, Val Acc: 0.6977
# Epoch Duration: 14.94 seconds
# Epoch 248/500, Train Loss: 0.2238, Train Acc: 0.9448, Val Loss: 0.7608, Val Acc: 0.7907
# Epoch Duration: 15.33 seconds
# Epoch 249/500, Train Loss: 0.1761, Train Acc: 0.9622, Val Loss: 0.9495, Val Acc: 0.7326
# Epoch Duration: 14.50 seconds
# Epoch 250/500, Train Loss: 0.2590, Train Acc: 0.9273, Val Loss: 0.9705, Val Acc: 0.6744
# Epoch Duration: 13.02 seconds
# Epoch 251/500, Train Loss: 0.1578, Train Acc: 0.9535, Val Loss: 0.6576, Val Acc: 0.7907
# Epoch Duration: 10.56 seconds
# Epoch 252/500, Train Loss: 0.1828, Train Acc: 0.9419, Val Loss: 0.7094, Val Acc: 0.8023
# Epoch Duration: 10.46 seconds
# Epoch 253/500, Train Loss: 0.2078, Train Acc: 0.9564, Val Loss: 0.8356, Val Acc: 0.7674
# Epoch Duration: 14.54 seconds
# Epoch 254/500, Train Loss: 0.1901, Train Acc: 0.9564, Val Loss: 1.0240, Val Acc: 0.6395
# Epoch Duration: 14.72 seconds
# Epoch 255/500, Train Loss: 0.1857, Train Acc: 0.9622, Val Loss: 0.6660, Val Acc: 0.8023
# Epoch Duration: 15.55 seconds
# Epoch 256/500, Train Loss: 0.1880, Train Acc: 0.9535, Val Loss: 0.7110, Val Acc: 0.7791
# Epoch Duration: 14.55 seconds
# Epoch 257/500, Train Loss: 0.1856, Train Acc: 0.9390, Val Loss: 0.8910, Val Acc: 0.7093
# Epoch Duration: 15.53 seconds
# Epoch 258/500, Train Loss: 0.2036, Train Acc: 0.9419, Val Loss: 0.9679, Val Acc: 0.7442
# Epoch Duration: 14.57 seconds
# Epoch 259/500, Train Loss: 0.1545, Train Acc: 0.9506, Val Loss: 0.8502, Val Acc: 0.7442
# Epoch Duration: 15.29 seconds
# Epoch 260/500, Train Loss: 0.1805, Train Acc: 0.9564, Val Loss: 0.7207, Val Acc: 0.8023
# Epoch Duration: 14.92 seconds
# Epoch 261/500, Train Loss: 0.1441, Train Acc: 0.9622, Val Loss: 0.6759, Val Acc: 0.7907
# Epoch Duration: 14.33 seconds
# Epoch 262/500, Train Loss: 0.1837, Train Acc: 0.9390, Val Loss: 0.6273, Val Acc: 0.7907
# Epoch Duration: 15.13 seconds
# Epoch 263/500, Train Loss: 0.1889, Train Acc: 0.9419, Val Loss: 0.6055, Val Acc: 0.7558
# Epoch Duration: 14.53 seconds
# Epoch 264/500, Train Loss: 0.1678, Train Acc: 0.9593, Val Loss: 0.6403, Val Acc: 0.8140
# Epoch Duration: 15.25 seconds
# Epoch 265/500, Train Loss: 0.1786, Train Acc: 0.9564, Val Loss: 0.7031, Val Acc: 0.7907
# Epoch Duration: 14.55 seconds
# Epoch 266/500, Train Loss: 0.2446, Train Acc: 0.9419, Val Loss: 0.7123, Val Acc: 0.7907
# Epoch Duration: 15.22 seconds
# Epoch 267/500, Train Loss: 0.1311, Train Acc: 0.9622, Val Loss: 0.7399, Val Acc: 0.7093
# Epoch Duration: 14.44 seconds
# Epoch 268/500, Train Loss: 0.1529, Train Acc: 0.9651, Val Loss: 0.6775, Val Acc: 0.7674
# Epoch Duration: 15.24 seconds
# Epoch 269/500, Train Loss: 0.2076, Train Acc: 0.9535, Val Loss: 0.7227, Val Acc: 0.7791
# Epoch Duration: 14.35 seconds
# Epoch 270/500, Train Loss: 0.2193, Train Acc: 0.9448, Val Loss: 0.8367, Val Acc: 0.7209
# Epoch Duration: 15.12 seconds
# Epoch 271/500, Train Loss: 0.1541, Train Acc: 0.9651, Val Loss: 0.7027, Val Acc: 0.7907
# Epoch Duration: 14.54 seconds
# Epoch 272/500, Train Loss: 0.1781, Train Acc: 0.9360, Val Loss: 0.9039, Val Acc: 0.7209
# Epoch Duration: 15.31 seconds
# Epoch 273/500, Train Loss: 0.1828, Train Acc: 0.9331, Val Loss: 0.8292, Val Acc: 0.7558
# Epoch Duration: 14.34 seconds
# Epoch 274/500, Train Loss: 0.1602, Train Acc: 0.9593, Val Loss: 0.6074, Val Acc: 0.7791
# Epoch Duration: 14.90 seconds
# Epoch 275/500, Train Loss: 0.1712, Train Acc: 0.9535, Val Loss: 0.7773, Val Acc: 0.7791
# Epoch Duration: 14.52 seconds
# Epoch 276/500, Train Loss: 0.1531, Train Acc: 0.9651, Val Loss: 0.8423, Val Acc: 0.7558
# Epoch Duration: 14.44 seconds
# Epoch 277/500, Train Loss: 0.1340, Train Acc: 0.9622, Val Loss: 0.6621, Val Acc: 0.8140
# Epoch Duration: 12.72 seconds
# Epoch 278/500, Train Loss: 0.1601, Train Acc: 0.9622, Val Loss: 0.5938, Val Acc: 0.8140
# Epoch Duration: 9.37 seconds
# Epoch 279/500, Train Loss: 0.1585, Train Acc: 0.9564, Val Loss: 0.6489, Val Acc: 0.8256
# Epoch Duration: 9.43 seconds
# Epoch 280/500, Train Loss: 0.1908, Train Acc: 0.9506, Val Loss: 0.6271, Val Acc: 0.7674
# Epoch Duration: 9.85 seconds
# Epoch 281/500, Train Loss: 0.1151, Train Acc: 0.9767, Val Loss: 0.6291, Val Acc: 0.8372
# Epoch Duration: 9.55 seconds
# Epoch 282/500, Train Loss: 0.1641, Train Acc: 0.9535, Val Loss: 0.5302, Val Acc: 0.8023
# Epoch Duration: 14.10 seconds
# Epoch 283/500, Train Loss: 0.1579, Train Acc: 0.9535, Val Loss: 0.9318, Val Acc: 0.7674
# Epoch Duration: 15.59 seconds
# Epoch 284/500, Train Loss: 0.1400, Train Acc: 0.9622, Val Loss: 0.7959, Val Acc: 0.7674
# Epoch Duration: 15.10 seconds
# Epoch 285/500, Train Loss: 0.1853, Train Acc: 0.9419, Val Loss: 0.8812, Val Acc: 0.7674
# Epoch Duration: 15.78 seconds
# Epoch 286/500, Train Loss: 0.1815, Train Acc: 0.9448, Val Loss: 0.8080, Val Acc: 0.7326
# Epoch Duration: 14.57 seconds
# Epoch 287/500, Train Loss: 0.1871, Train Acc: 0.9273, Val Loss: 0.7634, Val Acc: 0.8023
# Epoch Duration: 15.33 seconds
# Epoch 288/500, Train Loss: 0.1873, Train Acc: 0.9622, Val Loss: 0.8008, Val Acc: 0.7791
# Epoch Duration: 14.55 seconds
# Epoch 289/500, Train Loss: 0.1693, Train Acc: 0.9622, Val Loss: 0.9635, Val Acc: 0.7442
# Epoch Duration: 15.24 seconds
# Epoch 290/500, Train Loss: 0.1977, Train Acc: 0.9448, Val Loss: 0.7549, Val Acc: 0.7326
# Epoch Duration: 14.43 seconds
# Epoch 291/500, Train Loss: 0.1627, Train Acc: 0.9419, Val Loss: 0.9367, Val Acc: 0.7326
# Epoch Duration: 15.18 seconds
# Epoch 292/500, Train Loss: 0.1726, Train Acc: 0.9477, Val Loss: 0.7752, Val Acc: 0.7674
# Epoch Duration: 14.50 seconds
# Epoch 293/500, Train Loss: 0.1570, Train Acc: 0.9593, Val Loss: 0.8023, Val Acc: 0.7791
# Epoch Duration: 15.30 seconds
# Epoch 294/500, Train Loss: 0.1647, Train Acc: 0.9564, Val Loss: 0.8668, Val Acc: 0.7674
# Epoch Duration: 14.43 seconds
# Epoch 295/500, Train Loss: 0.1418, Train Acc: 0.9506, Val Loss: 0.8199, Val Acc: 0.7791
# Epoch Duration: 15.12 seconds
# Epoch 296/500, Train Loss: 0.1809, Train Acc: 0.9477, Val Loss: 0.9004, Val Acc: 0.7674
# Epoch Duration: 14.45 seconds
# Epoch 297/500, Train Loss: 0.1456, Train Acc: 0.9564, Val Loss: 0.8205, Val Acc: 0.7907
# Epoch Duration: 15.39 seconds
# Epoch 298/500, Train Loss: 0.1606, Train Acc: 0.9506, Val Loss: 0.5983, Val Acc: 0.8140
# Epoch Duration: 14.10 seconds
# Epoch 299/500, Train Loss: 0.1451, Train Acc: 0.9680, Val Loss: 0.7178, Val Acc: 0.7674
# Epoch Duration: 9.43 seconds
# Epoch 300/500, Train Loss: 0.1767, Train Acc: 0.9506, Val Loss: 0.8338, Val Acc: 0.7442
# Epoch Duration: 9.77 seconds
# Epoch 301/500, Train Loss: 0.1690, Train Acc: 0.9564, Val Loss: 0.6751, Val Acc: 0.7791
# Epoch Duration: 9.44 seconds
# Epoch 302/500, Train Loss: 0.2477, Train Acc: 0.9593, Val Loss: 0.7063, Val Acc: 0.7791
# Epoch Duration: 9.72 seconds
# Epoch 303/500, Train Loss: 0.1701, Train Acc: 0.9302, Val Loss: 0.9659, Val Acc: 0.7558
# Epoch Duration: 13.87 seconds
# Epoch 304/500, Train Loss: 0.1854, Train Acc: 0.9506, Val Loss: 0.6321, Val Acc: 0.7674
# Epoch Duration: 13.79 seconds
# Epoch 305/500, Train Loss: 0.1425, Train Acc: 0.9535, Val Loss: 0.8230, Val Acc: 0.7209
# Epoch Duration: 9.52 seconds
# Epoch 306/500, Train Loss: 0.1542, Train Acc: 0.9564, Val Loss: 0.7215, Val Acc: 0.7326
# Epoch Duration: 10.01 seconds
# Epoch 307/500, Train Loss: 0.1459, Train Acc: 0.9506, Val Loss: 0.6829, Val Acc: 0.7326
# Epoch Duration: 9.79 seconds
# Epoch 308/500, Train Loss: 0.1612, Train Acc: 0.9360, Val Loss: 0.7307, Val Acc: 0.7209
# Epoch Duration: 9.72 seconds
# Epoch 309/500, Train Loss: 0.1680, Train Acc: 0.9535, Val Loss: 0.7981, Val Acc: 0.6860
# Epoch Duration: 12.51 seconds
# Epoch 310/500, Train Loss: 0.1246, Train Acc: 0.9622, Val Loss: 0.7578, Val Acc: 0.8023
# Epoch Duration: 10.30 seconds
# Epoch 311/500, Train Loss: 0.1769, Train Acc: 0.9273, Val Loss: 0.7496, Val Acc: 0.7558
# Epoch Duration: 10.69 seconds
# Epoch 312/500, Train Loss: 0.1831, Train Acc: 0.9564, Val Loss: 0.6720, Val Acc: 0.7907
# Epoch Duration: 16.05 seconds
# Epoch 313/500, Train Loss: 0.1497, Train Acc: 0.9506, Val Loss: 0.6745, Val Acc: 0.7093
# Epoch Duration: 15.27 seconds
# Epoch 314/500, Train Loss: 0.1586, Train Acc: 0.9564, Val Loss: 0.7303, Val Acc: 0.7791
# Epoch Duration: 15.21 seconds
# Epoch 315/500, Train Loss: 0.1678, Train Acc: 0.9535, Val Loss: 0.7110, Val Acc: 0.7326
# Epoch Duration: 10.76 seconds
# Epoch 316/500, Train Loss: 0.1499, Train Acc: 0.9535, Val Loss: 0.6189, Val Acc: 0.8023
# Epoch Duration: 11.01 seconds
# Epoch 317/500, Train Loss: 0.2111, Train Acc: 0.9360, Val Loss: 0.9445, Val Acc: 0.7093
# Epoch Duration: 14.64 seconds
# Epoch 318/500, Train Loss: 0.1991, Train Acc: 0.9331, Val Loss: 0.7803, Val Acc: 0.7442
# Epoch Duration: 15.67 seconds
# Epoch 319/500, Train Loss: 0.1332, Train Acc: 0.9448, Val Loss: 0.9493, Val Acc: 0.7558
# Epoch Duration: 14.84 seconds
# Epoch 320/500, Train Loss: 0.1959, Train Acc: 0.9593, Val Loss: 0.6702, Val Acc: 0.7791
# Epoch Duration: 14.80 seconds
# Epoch 321/500, Train Loss: 0.1793, Train Acc: 0.9448, Val Loss: 0.8555, Val Acc: 0.7442
# Epoch Duration: 15.46 seconds
# Epoch 322/500, Train Loss: 0.1264, Train Acc: 0.9564, Val Loss: 0.6906, Val Acc: 0.7558
# Epoch Duration: 14.87 seconds
# Epoch 323/500, Train Loss: 0.1655, Train Acc: 0.9506, Val Loss: 0.6756, Val Acc: 0.7791
# Epoch Duration: 12.82 seconds
# Epoch 324/500, Train Loss: 0.1295, Train Acc: 0.9651, Val Loss: 0.7907, Val Acc: 0.7674
# Epoch Duration: 10.40 seconds
# Epoch 325/500, Train Loss: 0.1682, Train Acc: 0.9477, Val Loss: 0.6616, Val Acc: 0.7791
# Epoch Duration: 10.69 seconds
# Epoch 326/500, Train Loss: 0.1465, Train Acc: 0.9709, Val Loss: 0.7333, Val Acc: 0.7442
# Epoch Duration: 14.02 seconds
# Epoch 327/500, Train Loss: 0.1208, Train Acc: 0.9593, Val Loss: 0.7706, Val Acc: 0.8023
# Epoch Duration: 14.67 seconds
# Epoch 328/500, Train Loss: 0.1531, Train Acc: 0.9535, Val Loss: 0.8334, Val Acc: 0.7326
# Epoch Duration: 11.25 seconds
# Epoch 329/500, Train Loss: 0.1632, Train Acc: 0.9564, Val Loss: 0.7324, Val Acc: 0.7674
# Epoch Duration: 10.49 seconds
# Epoch 330/500, Train Loss: 0.1397, Train Acc: 0.9680, Val Loss: 0.7043, Val Acc: 0.7791
# Epoch Duration: 14.29 seconds
# Epoch 331/500, Train Loss: 0.1344, Train Acc: 0.9535, Val Loss: 0.5641, Val Acc: 0.8605
# Epoch Duration: 10.72 seconds
# Epoch 332/500, Train Loss: 0.1242, Train Acc: 0.9651, Val Loss: 0.7458, Val Acc: 0.7674
# Epoch Duration: 10.66 seconds
# Epoch 333/500, Train Loss: 0.1491, Train Acc: 0.9506, Val Loss: 0.6998, Val Acc: 0.7907
# Epoch Duration: 12.94 seconds
# Epoch 334/500, Train Loss: 0.1294, Train Acc: 0.9593, Val Loss: 0.6528, Val Acc: 0.7907
# Epoch Duration: 10.67 seconds
# Epoch 335/500, Train Loss: 0.1768, Train Acc: 0.9535, Val Loss: 0.6384, Val Acc: 0.7791
# Epoch Duration: 10.64 seconds
# Epoch 336/500, Train Loss: 0.1572, Train Acc: 0.9622, Val Loss: 0.5240, Val Acc: 0.7907
# Epoch Duration: 15.79 seconds
# Epoch 337/500, Train Loss: 0.1728, Train Acc: 0.9564, Val Loss: 0.6251, Val Acc: 0.7907
# Epoch Duration: 14.71 seconds
# Epoch 338/500, Train Loss: 0.1086, Train Acc: 0.9651, Val Loss: 0.7323, Val Acc: 0.7907
# Epoch Duration: 15.44 seconds
# Epoch 339/500, Train Loss: 0.1317, Train Acc: 0.9651, Val Loss: 0.7281, Val Acc: 0.7907
# Epoch Duration: 14.83 seconds
# Epoch 340/500, Train Loss: 0.1212, Train Acc: 0.9651, Val Loss: 0.7049, Val Acc: 0.7442
# Epoch Duration: 15.55 seconds
# Epoch 341/500, Train Loss: 0.1471, Train Acc: 0.9593, Val Loss: 0.7169, Val Acc: 0.7907
# Epoch Duration: 14.66 seconds
# Epoch 342/500, Train Loss: 0.1116, Train Acc: 0.9651, Val Loss: 0.5299, Val Acc: 0.8140
# Epoch Duration: 15.25 seconds
# Epoch 343/500, Train Loss: 0.1249, Train Acc: 0.9680, Val Loss: 0.7454, Val Acc: 0.7791
# Epoch Duration: 14.44 seconds
# Epoch 344/500, Train Loss: 0.1490, Train Acc: 0.9477, Val Loss: 0.9452, Val Acc: 0.7093
# Epoch Duration: 15.63 seconds
# Epoch 345/500, Train Loss: 0.1031, Train Acc: 0.9651, Val Loss: 0.6258, Val Acc: 0.7674
# Epoch Duration: 14.46 seconds
# Epoch 346/500, Train Loss: 0.1194, Train Acc: 0.9622, Val Loss: 0.6223, Val Acc: 0.8140
# Epoch Duration: 15.28 seconds
# Epoch 347/500, Train Loss: 0.1485, Train Acc: 0.9651, Val Loss: 0.7206, Val Acc: 0.7442
# Epoch Duration: 14.82 seconds
# Epoch 348/500, Train Loss: 0.1784, Train Acc: 0.9535, Val Loss: 0.8522, Val Acc: 0.7558
# Epoch Duration: 14.84 seconds
# Epoch 349/500, Train Loss: 0.1007, Train Acc: 0.9593, Val Loss: 0.5702, Val Acc: 0.8372
# Epoch Duration: 14.99 seconds
# Epoch 350/500, Train Loss: 0.1270, Train Acc: 0.9709, Val Loss: 0.5870, Val Acc: 0.8256
# Epoch Duration: 14.24 seconds
# Epoch 351/500, Train Loss: 0.1252, Train Acc: 0.9564, Val Loss: 0.9910, Val Acc: 0.7674
# Epoch Duration: 15.41 seconds
# Epoch 352/500, Train Loss: 0.1127, Train Acc: 0.9680, Val Loss: 0.5971, Val Acc: 0.8140
# Epoch Duration: 14.62 seconds
# Epoch 353/500, Train Loss: 0.1356, Train Acc: 0.9680, Val Loss: 0.8472, Val Acc: 0.7674
# Epoch Duration: 14.46 seconds
# Epoch 354/500, Train Loss: 0.1266, Train Acc: 0.9622, Val Loss: 0.7364, Val Acc: 0.7674
# Epoch Duration: 9.41 seconds
# Epoch 355/500, Train Loss: 0.1260, Train Acc: 0.9651, Val Loss: 0.8222, Val Acc: 0.7674
# Epoch Duration: 9.33 seconds
# Epoch 356/500, Train Loss: 0.1357, Train Acc: 0.9622, Val Loss: 0.7445, Val Acc: 0.7674
# Epoch Duration: 12.32 seconds
# Epoch 357/500, Train Loss: 0.1053, Train Acc: 0.9767, Val Loss: 0.6876, Val Acc: 0.7674
# Epoch Duration: 14.96 seconds
# Epoch 358/500, Train Loss: 0.1194, Train Acc: 0.9593, Val Loss: 0.7921, Val Acc: 0.7907
# Epoch Duration: 15.55 seconds
# Epoch 359/500, Train Loss: 0.1429, Train Acc: 0.9448, Val Loss: 0.8261, Val Acc: 0.8023
# Epoch Duration: 14.49 seconds
# Epoch 360/500, Train Loss: 0.1542, Train Acc: 0.9477, Val Loss: 0.6809, Val Acc: 0.8023
# Epoch Duration: 15.11 seconds
# Epoch 361/500, Train Loss: 0.1318, Train Acc: 0.9535, Val Loss: 0.6314, Val Acc: 0.8605
# Epoch Duration: 14.33 seconds
# Epoch 362/500, Train Loss: 0.1409, Train Acc: 0.9535, Val Loss: 0.7262, Val Acc: 0.7558
# Epoch Duration: 14.95 seconds
# Epoch 363/500, Train Loss: 0.1324, Train Acc: 0.9564, Val Loss: 0.8272, Val Acc: 0.8140
# Epoch Duration: 14.82 seconds
# Epoch 364/500, Train Loss: 0.1381, Train Acc: 0.9564, Val Loss: 0.6673, Val Acc: 0.7907
# Epoch Duration: 16.23 seconds
# Epoch 365/500, Train Loss: 0.1620, Train Acc: 0.9477, Val Loss: 0.5622, Val Acc: 0.7674
# Epoch Duration: 9.52 seconds
# Epoch 366/500, Train Loss: 0.1171, Train Acc: 0.9680, Val Loss: 0.6700, Val Acc: 0.7907
# Epoch Duration: 9.38 seconds
# Epoch 367/500, Train Loss: 0.1476, Train Acc: 0.9564, Val Loss: 0.7661, Val Acc: 0.8023
# Epoch Duration: 12.79 seconds
# Epoch 368/500, Train Loss: 0.0977, Train Acc: 0.9738, Val Loss: 0.7219, Val Acc: 0.7674
# Epoch Duration: 14.87 seconds
# Epoch 369/500, Train Loss: 0.1157, Train Acc: 0.9593, Val Loss: 0.7538, Val Acc: 0.8023
# Epoch Duration: 15.66 seconds
# Epoch 370/500, Train Loss: 0.1264, Train Acc: 0.9593, Val Loss: 0.7154, Val Acc: 0.7674
# Epoch Duration: 14.88 seconds
# Epoch 371/500, Train Loss: 0.1318, Train Acc: 0.9593, Val Loss: 0.5305, Val Acc: 0.8023
# Epoch Duration: 14.72 seconds
# Epoch 372/500, Train Loss: 0.0725, Train Acc: 0.9767, Val Loss: 0.6891, Val Acc: 0.7791
# Epoch Duration: 9.55 seconds
# Epoch 373/500, Train Loss: 0.1044, Train Acc: 0.9651, Val Loss: 0.6904, Val Acc: 0.7791
# Epoch Duration: 9.47 seconds
# Epoch 374/500, Train Loss: 0.1197, Train Acc: 0.9622, Val Loss: 0.7134, Val Acc: 0.7674
# Epoch Duration: 10.46 seconds
# Epoch 375/500, Train Loss: 0.0962, Train Acc: 0.9738, Val Loss: 0.8452, Val Acc: 0.7791
# Epoch Duration: 10.01 seconds
# Epoch 376/500, Train Loss: 0.1060, Train Acc: 0.9593, Val Loss: 0.6982, Val Acc: 0.7791
# Epoch Duration: 9.77 seconds
# Epoch 377/500, Train Loss: 0.0862, Train Acc: 0.9826, Val Loss: 0.6424, Val Acc: 0.7558
# Epoch Duration: 13.25 seconds
# Epoch 378/500, Train Loss: 0.1045, Train Acc: 0.9622, Val Loss: 0.6082, Val Acc: 0.7791
# Epoch Duration: 10.04 seconds
# Epoch 379/500, Train Loss: 0.0797, Train Acc: 0.9767, Val Loss: 0.5966, Val Acc: 0.7907
# Epoch Duration: 9.69 seconds
# Epoch 380/500, Train Loss: 0.1120, Train Acc: 0.9680, Val Loss: 0.6004, Val Acc: 0.8023
# Epoch Duration: 13.14 seconds
# Epoch 381/500, Train Loss: 0.1174, Train Acc: 0.9651, Val Loss: 0.5735, Val Acc: 0.8023
# Epoch Duration: 10.73 seconds
# Epoch 382/500, Train Loss: 0.0999, Train Acc: 0.9680, Val Loss: 0.5785, Val Acc: 0.7558
# Epoch Duration: 11.02 seconds
# Epoch 383/500, Train Loss: 0.1154, Train Acc: 0.9738, Val Loss: 0.5774, Val Acc: 0.8256
# Epoch Duration: 16.16 seconds
# Epoch 384/500, Train Loss: 0.1143, Train Acc: 0.9506, Val Loss: 0.7052, Val Acc: 0.7791
# Epoch Duration: 14.87 seconds
# Epoch 385/500, Train Loss: 0.1285, Train Acc: 0.9535, Val Loss: 0.7949, Val Acc: 0.7791
# Epoch Duration: 15.96 seconds
# Epoch 386/500, Train Loss: 0.1009, Train Acc: 0.9767, Val Loss: 0.8030, Val Acc: 0.7791
# Epoch Duration: 14.81 seconds
# Epoch 387/500, Train Loss: 0.1388, Train Acc: 0.9622, Val Loss: 0.7375, Val Acc: 0.7442
# Epoch Duration: 15.42 seconds
# Epoch 388/500, Train Loss: 0.1509, Train Acc: 0.9622, Val Loss: 0.5278, Val Acc: 0.8605
# Epoch Duration: 14.75 seconds
# Epoch 389/500, Train Loss: 0.1246, Train Acc: 0.9651, Val Loss: 0.8389, Val Acc: 0.7209
# Epoch Duration: 15.91 seconds
# Epoch 390/500, Train Loss: 0.1046, Train Acc: 0.9622, Val Loss: 0.5460, Val Acc: 0.8023
# Epoch Duration: 14.44 seconds
# Epoch 391/500, Train Loss: 0.1914, Train Acc: 0.9506, Val Loss: 0.5675, Val Acc: 0.8023
# Epoch Duration: 15.51 seconds
# Epoch 392/500, Train Loss: 0.0924, Train Acc: 0.9767, Val Loss: 0.7813, Val Acc: 0.7442
# Epoch Duration: 14.62 seconds
# Epoch 393/500, Train Loss: 0.1321, Train Acc: 0.9506, Val Loss: 0.6391, Val Acc: 0.7674
# Epoch Duration: 15.17 seconds
# Epoch 394/500, Train Loss: 0.1137, Train Acc: 0.9622, Val Loss: 0.6043, Val Acc: 0.8372
# Epoch Duration: 14.68 seconds
# Epoch 395/500, Train Loss: 0.1153, Train Acc: 0.9826, Val Loss: 0.6754, Val Acc: 0.7907
# Epoch Duration: 14.48 seconds
# Epoch 396/500, Train Loss: 0.1369, Train Acc: 0.9622, Val Loss: 0.7000, Val Acc: 0.7558
# Epoch Duration: 15.25 seconds
# Epoch 397/500, Train Loss: 0.1078, Train Acc: 0.9680, Val Loss: 0.7387, Val Acc: 0.7791
# Epoch Duration: 15.13 seconds
# Epoch 398/500, Train Loss: 0.1527, Train Acc: 0.9535, Val Loss: 0.7340, Val Acc: 0.7442
# Epoch Duration: 15.05 seconds
# Epoch 399/500, Train Loss: 0.1070, Train Acc: 0.9680, Val Loss: 0.6461, Val Acc: 0.8140
# Epoch Duration: 14.25 seconds
# Epoch 400/500, Train Loss: 0.0866, Train Acc: 0.9767, Val Loss: 0.7108, Val Acc: 0.7907
# Epoch Duration: 15.25 seconds
# Epoch 401/500, Train Loss: 0.1238, Train Acc: 0.9622, Val Loss: 0.7650, Val Acc: 0.7209
# Epoch Duration: 14.49 seconds
# Epoch 402/500, Train Loss: 0.1436, Train Acc: 0.9622, Val Loss: 0.8420, Val Acc: 0.7442
# Epoch Duration: 15.10 seconds
# Epoch 403/500, Train Loss: 0.1148, Train Acc: 0.9797, Val Loss: 0.5585, Val Acc: 0.8140
# Epoch Duration: 14.29 seconds
# Epoch 404/500, Train Loss: 0.1221, Train Acc: 0.9651, Val Loss: 0.7632, Val Acc: 0.7093
# Epoch Duration: 15.06 seconds
# Epoch 405/500, Train Loss: 0.1315, Train Acc: 0.9622, Val Loss: 0.7265, Val Acc: 0.7674
# Epoch Duration: 14.55 seconds
# Epoch 406/500, Train Loss: 0.1279, Train Acc: 0.9622, Val Loss: 0.5699, Val Acc: 0.8256
# Epoch Duration: 14.64 seconds
# Epoch 407/500, Train Loss: 0.1241, Train Acc: 0.9651, Val Loss: 0.7655, Val Acc: 0.7907
# Epoch Duration: 10.46 seconds
# Epoch 408/500, Train Loss: 0.0847, Train Acc: 0.9797, Val Loss: 0.8630, Val Acc: 0.6860
# Epoch Duration: 10.48 seconds
# Epoch 409/500, Train Loss: 0.1369, Train Acc: 0.9535, Val Loss: 0.7741, Val Acc: 0.7326
# Epoch Duration: 15.19 seconds
# Epoch 410/500, Train Loss: 0.0840, Train Acc: 0.9767, Val Loss: 0.7522, Val Acc: 0.7093
# Epoch Duration: 10.59 seconds
# Epoch 411/500, Train Loss: 0.1201, Train Acc: 0.9680, Val Loss: 0.7000, Val Acc: 0.8023
# Epoch Duration: 10.66 seconds
# Epoch 412/500, Train Loss: 0.1302, Train Acc: 0.9593, Val Loss: 0.8892, Val Acc: 0.7558
# Epoch Duration: 14.71 seconds
# Epoch 413/500, Train Loss: 0.1546, Train Acc: 0.9622, Val Loss: 0.8068, Val Acc: 0.7558
# Epoch Duration: 15.00 seconds
# Epoch 414/500, Train Loss: 0.1148, Train Acc: 0.9680, Val Loss: 0.8669, Val Acc: 0.7674
# Epoch Duration: 15.71 seconds
# Epoch 415/500, Train Loss: 0.1106, Train Acc: 0.9593, Val Loss: 1.0681, Val Acc: 0.7558
# Epoch Duration: 14.51 seconds
# Epoch 416/500, Train Loss: 0.1225, Train Acc: 0.9709, Val Loss: 0.7210, Val Acc: 0.7558
# Epoch Duration: 15.24 seconds
# Epoch 417/500, Train Loss: 0.1283, Train Acc: 0.9622, Val Loss: 0.7649, Val Acc: 0.7558
# Epoch Duration: 14.53 seconds
# Epoch 418/500, Train Loss: 0.1093, Train Acc: 0.9709, Val Loss: 0.6909, Val Acc: 0.8140
# Epoch Duration: 12.99 seconds
# Epoch 419/500, Train Loss: 0.1143, Train Acc: 0.9767, Val Loss: 0.6815, Val Acc: 0.7907
# Epoch Duration: 10.41 seconds
# Epoch 420/500, Train Loss: 0.1341, Train Acc: 0.9709, Val Loss: 0.6475, Val Acc: 0.8256
# Epoch Duration: 10.38 seconds
# Epoch 421/500, Train Loss: 0.1251, Train Acc: 0.9709, Val Loss: 0.6642, Val Acc: 0.8023
# Epoch Duration: 14.46 seconds
# Epoch 422/500, Train Loss: 0.1072, Train Acc: 0.9680, Val Loss: 0.6131, Val Acc: 0.7674
# Epoch Duration: 14.92 seconds
# Epoch 423/500, Train Loss: 0.1154, Train Acc: 0.9622, Val Loss: 0.5195, Val Acc: 0.8256
# Epoch Duration: 15.41 seconds
# Epoch 424/500, Train Loss: 0.0740, Train Acc: 0.9913, Val Loss: 0.6971, Val Acc: 0.8023
# Epoch Duration: 14.54 seconds
# Epoch 425/500, Train Loss: 0.1265, Train Acc: 0.9535, Val Loss: 0.5931, Val Acc: 0.8372
# Epoch Duration: 15.25 seconds
# Epoch 426/500, Train Loss: 0.1315, Train Acc: 0.9622, Val Loss: 0.8236, Val Acc: 0.7326
# Epoch Duration: 14.51 seconds
# Epoch 427/500, Train Loss: 0.1360, Train Acc: 0.9651, Val Loss: 0.6782, Val Acc: 0.7907
# Epoch Duration: 15.47 seconds
# Epoch 428/500, Train Loss: 0.0921, Train Acc: 0.9767, Val Loss: 0.7029, Val Acc: 0.7209
# Epoch Duration: 14.37 seconds
# Epoch 429/500, Train Loss: 0.1005, Train Acc: 0.9797, Val Loss: 0.7120, Val Acc: 0.7558
# Epoch Duration: 14.35 seconds
# Epoch 430/500, Train Loss: 0.1063, Train Acc: 0.9680, Val Loss: 0.8199, Val Acc: 0.6977
# Epoch Duration: 15.14 seconds
# Epoch 431/500, Train Loss: 0.0844, Train Acc: 0.9826, Val Loss: 0.7942, Val Acc: 0.7907
# Epoch Duration: 14.55 seconds
# Epoch 432/500, Train Loss: 0.1209, Train Acc: 0.9564, Val Loss: 0.6321, Val Acc: 0.7907
# Epoch Duration: 15.18 seconds
# Epoch 433/500, Train Loss: 0.1095, Train Acc: 0.9709, Val Loss: 0.8283, Val Acc: 0.7558
# Epoch Duration: 10.25 seconds
# Epoch 434/500, Train Loss: 0.1323, Train Acc: 0.9651, Val Loss: 0.4811, Val Acc: 0.8023
# Epoch Duration: 11.02 seconds
# Epoch 435/500, Train Loss: 0.1558, Train Acc: 0.9448, Val Loss: 0.7826, Val Acc: 0.7442
# Epoch Duration: 12.93 seconds
# Epoch 436/500, Train Loss: 0.1269, Train Acc: 0.9622, Val Loss: 0.7456, Val Acc: 0.7442
# Epoch Duration: 14.86 seconds
# Epoch 437/500, Train Loss: 0.0959, Train Acc: 0.9767, Val Loss: 0.7211, Val Acc: 0.7558
# Epoch Duration: 15.49 seconds
# Epoch 438/500, Train Loss: 0.1004, Train Acc: 0.9709, Val Loss: 0.6868, Val Acc: 0.7558
# Epoch Duration: 14.63 seconds
# Epoch 439/500, Train Loss: 0.0849, Train Acc: 0.9709, Val Loss: 0.6696, Val Acc: 0.7907
# Epoch Duration: 15.24 seconds
# Epoch 440/500, Train Loss: 0.0851, Train Acc: 0.9709, Val Loss: 0.7846, Val Acc: 0.7558
# Epoch Duration: 14.63 seconds
# Epoch 441/500, Train Loss: 0.0849, Train Acc: 0.9767, Val Loss: 0.7923, Val Acc: 0.7674
# Epoch Duration: 15.10 seconds
# Epoch 442/500, Train Loss: 0.0937, Train Acc: 0.9593, Val Loss: 0.6018, Val Acc: 0.7558
# Epoch Duration: 14.41 seconds
# Epoch 443/500, Train Loss: 0.0958, Train Acc: 0.9738, Val Loss: 0.8151, Val Acc: 0.7674
# Epoch Duration: 15.16 seconds
# Epoch 444/500, Train Loss: 0.1315, Train Acc: 0.9622, Val Loss: 0.8309, Val Acc: 0.7558
# Epoch Duration: 14.64 seconds
# Epoch 445/500, Train Loss: 0.0935, Train Acc: 0.9709, Val Loss: 0.9402, Val Acc: 0.7558
# Epoch Duration: 15.03 seconds
# Epoch 446/500, Train Loss: 0.1047, Train Acc: 0.9651, Val Loss: 0.7748, Val Acc: 0.8140
# Epoch Duration: 14.33 seconds
# Epoch 447/500, Train Loss: 0.0805, Train Acc: 0.9738, Val Loss: 0.8288, Val Acc: 0.7558
# Epoch Duration: 14.89 seconds
# Epoch 448/500, Train Loss: 0.1082, Train Acc: 0.9564, Val Loss: 0.8493, Val Acc: 0.7674
# Epoch Duration: 14.61 seconds
# Epoch 449/500, Train Loss: 0.0971, Train Acc: 0.9709, Val Loss: 0.8578, Val Acc: 0.6744
# Epoch Duration: 14.58 seconds
# Epoch 450/500, Train Loss: 0.1070, Train Acc: 0.9709, Val Loss: 0.5978, Val Acc: 0.8023
# Epoch Duration: 14.74 seconds
# Epoch 451/500, Train Loss: 0.0825, Train Acc: 0.9680, Val Loss: 0.5367, Val Acc: 0.8721
# Epoch Duration: 14.43 seconds
# Epoch 452/500, Train Loss: 0.1057, Train Acc: 0.9622, Val Loss: 0.7563, Val Acc: 0.7442
# Epoch Duration: 16.34 seconds
# Epoch 453/500, Train Loss: 0.0742, Train Acc: 0.9622, Val Loss: 0.7344, Val Acc: 0.7674
# Epoch Duration: 14.39 seconds
# Epoch 454/500, Train Loss: 0.1049, Train Acc: 0.9709, Val Loss: 0.6801, Val Acc: 0.7442
# Epoch Duration: 15.18 seconds
# Epoch 455/500, Train Loss: 0.1082, Train Acc: 0.9738, Val Loss: 0.7049, Val Acc: 0.8023
# Epoch Duration: 14.58 seconds
# Epoch 456/500, Train Loss: 0.0908, Train Acc: 0.9680, Val Loss: 1.0085, Val Acc: 0.7558
# Epoch Duration: 15.74 seconds
# Epoch 457/500, Train Loss: 0.0950, Train Acc: 0.9767, Val Loss: 0.7285, Val Acc: 0.7674
# Epoch Duration: 13.89 seconds
# Epoch 458/500, Train Loss: 0.1003, Train Acc: 0.9709, Val Loss: 0.7904, Val Acc: 0.7442
# Epoch Duration: 9.80 seconds
# Epoch 459/500, Train Loss: 0.0806, Train Acc: 0.9767, Val Loss: 0.7424, Val Acc: 0.7674
# Epoch Duration: 9.46 seconds
# Epoch 460/500, Train Loss: 0.1072, Train Acc: 0.9709, Val Loss: 0.7849, Val Acc: 0.7674
# Epoch Duration: 11.41 seconds
# Epoch 461/500, Train Loss: 0.1057, Train Acc: 0.9680, Val Loss: 0.8327, Val Acc: 0.7791
# Epoch Duration: 15.69 seconds
# Epoch 462/500, Train Loss: 0.1229, Train Acc: 0.9622, Val Loss: 0.8284, Val Acc: 0.7209
# Epoch Duration: 14.61 seconds
# Epoch 463/500, Train Loss: 0.1023, Train Acc: 0.9709, Val Loss: 0.6579, Val Acc: 0.7791
# Epoch Duration: 15.36 seconds
# Epoch 464/500, Train Loss: 0.0942, Train Acc: 0.9738, Val Loss: 0.7410, Val Acc: 0.7558
# Epoch Duration: 14.46 seconds
# Epoch 465/500, Train Loss: 0.1098, Train Acc: 0.9738, Val Loss: 0.7892, Val Acc: 0.8140
# Epoch Duration: 15.35 seconds
# Epoch 466/500, Train Loss: 0.0860, Train Acc: 0.9680, Val Loss: 0.8305, Val Acc: 0.7674
# Epoch Duration: 14.41 seconds
# Epoch 467/500, Train Loss: 0.1130, Train Acc: 0.9738, Val Loss: 0.6059, Val Acc: 0.8256
# Epoch Duration: 15.02 seconds
# Epoch 468/500, Train Loss: 0.1100, Train Acc: 0.9709, Val Loss: 0.7131, Val Acc: 0.8256
# Epoch Duration: 14.38 seconds
# Epoch 469/500, Train Loss: 0.1269, Train Acc: 0.9622, Val Loss: 0.7880, Val Acc: 0.7907
# Epoch Duration: 17.17 seconds
# Epoch 470/500, Train Loss: 0.1216, Train Acc: 0.9593, Val Loss: 0.6402, Val Acc: 0.8023
# Epoch Duration: 14.36 seconds
# Epoch 471/500, Train Loss: 0.0965, Train Acc: 0.9767, Val Loss: 0.6293, Val Acc: 0.7791
# Epoch Duration: 14.98 seconds
# Epoch 472/500, Train Loss: 0.0798, Train Acc: 0.9855, Val Loss: 0.8217, Val Acc: 0.7674
# Epoch Duration: 15.09 seconds
# Epoch 473/500, Train Loss: 0.1062, Train Acc: 0.9738, Val Loss: 0.6288, Val Acc: 0.7674
# Epoch Duration: 14.78 seconds
# Epoch 474/500, Train Loss: 0.1247, Train Acc: 0.9651, Val Loss: 0.5354, Val Acc: 0.7674
# Epoch Duration: 15.11 seconds
# Epoch 475/500, Train Loss: 0.0938, Train Acc: 0.9797, Val Loss: 0.5849, Val Acc: 0.7791
# Epoch Duration: 14.32 seconds
# Epoch 476/500, Train Loss: 0.0862, Train Acc: 0.9767, Val Loss: 0.5264, Val Acc: 0.8023
# Epoch Duration: 15.55 seconds
# Epoch 477/500, Train Loss: 0.0939, Train Acc: 0.9651, Val Loss: 0.8073, Val Acc: 0.7907
# Epoch Duration: 14.56 seconds
# Epoch 478/500, Train Loss: 0.0994, Train Acc: 0.9680, Val Loss: 0.6199, Val Acc: 0.7907
# Epoch Duration: 15.32 seconds
# Epoch 479/500, Train Loss: 0.1173, Train Acc: 0.9593, Val Loss: 0.6894, Val Acc: 0.7791
# Epoch Duration: 14.20 seconds
# Epoch 480/500, Train Loss: 0.1085, Train Acc: 0.9680, Val Loss: 0.7156, Val Acc: 0.7326
# Epoch Duration: 15.23 seconds
# Epoch 481/500, Train Loss: 0.0897, Train Acc: 0.9738, Val Loss: 0.6802, Val Acc: 0.7674
# Epoch Duration: 14.91 seconds
# Epoch 482/500, Train Loss: 0.0883, Train Acc: 0.9797, Val Loss: 0.8942, Val Acc: 0.7442
# Epoch Duration: 14.41 seconds
# Epoch 483/500, Train Loss: 0.1315, Train Acc: 0.9564, Val Loss: 0.7648, Val Acc: 0.7558
# Epoch Duration: 9.35 seconds
# Epoch 484/500, Train Loss: 0.0607, Train Acc: 0.9826, Val Loss: 0.6998, Val Acc: 0.7674
# Epoch Duration: 9.40 seconds
# Epoch 485/500, Train Loss: 0.1089, Train Acc: 0.9709, Val Loss: 0.7939, Val Acc: 0.7791
# Epoch Duration: 10.35 seconds
# Epoch 486/500, Train Loss: 0.0805, Train Acc: 0.9709, Val Loss: 0.6922, Val Acc: 0.7907
# Epoch Duration: 9.89 seconds
# Epoch 487/500, Train Loss: 0.1348, Train Acc: 0.9709, Val Loss: 0.6658, Val Acc: 0.8140
# Epoch Duration: 14.23 seconds
# Epoch 488/500, Train Loss: 0.0827, Train Acc: 0.9709, Val Loss: 0.7833, Val Acc: 0.7558
# Epoch Duration: 16.38 seconds
# Epoch 489/500, Train Loss: 0.0702, Train Acc: 0.9826, Val Loss: 0.7105, Val Acc: 0.7674
# Epoch Duration: 9.52 seconds
# Epoch 490/500, Train Loss: 0.0847, Train Acc: 0.9767, Val Loss: 0.7376, Val Acc: 0.7442
# Epoch Duration: 9.40 seconds
# Epoch 491/500, Train Loss: 0.0873, Train Acc: 0.9709, Val Loss: 0.6552, Val Acc: 0.8256
# Epoch Duration: 11.93 seconds
# Epoch 492/500, Train Loss: 0.0960, Train Acc: 0.9651, Val Loss: 0.6963, Val Acc: 0.7791
# Epoch Duration: 9.76 seconds
# Epoch 493/500, Train Loss: 0.1101, Train Acc: 0.9709, Val Loss: 0.8385, Val Acc: 0.7791
# Epoch Duration: 9.68 seconds
# Epoch 494/500, Train Loss: 0.1078, Train Acc: 0.9564, Val Loss: 0.5629, Val Acc: 0.8140
# Epoch Duration: 15.33 seconds
# Epoch 495/500, Train Loss: 0.1179, Train Acc: 0.9651, Val Loss: 0.7462, Val Acc: 0.7209
# Epoch Duration: 15.02 seconds
# Epoch 496/500, Train Loss: 0.1307, Train Acc: 0.9622, Val Loss: 0.6082, Val Acc: 0.7907
# Epoch Duration: 16.05 seconds
# Epoch 497/500, Train Loss: 0.1043, Train Acc: 0.9738, Val Loss: 0.6949, Val Acc: 0.7674
# Epoch Duration: 14.94 seconds
# Epoch 498/500, Train Loss: 0.0874, Train Acc: 0.9680, Val Loss: 0.7025, Val Acc: 0.7558
# Epoch Duration: 15.70 seconds
# Epoch 499/500, Train Loss: 0.0958, Train Acc: 0.9651, Val Loss: 0.7536, Val Acc: 0.7674
# Epoch Duration: 10.91 seconds
# Epoch 500/500, Train Loss: 0.1063, Train Acc: 0.9767, Val Loss: 0.8490, Val Acc: 0.7791
# Epoch Duration: 11.14 seconds
# Total Training Time: 6953.04 seconds
# Final Evaluation on Validation Set:
# Accuracy: 0.7791
# Precision: 0.7636
# Recall: 0.7549
# F1-Score: 0.7464

# %%
class_names
# Out:
# ['valobasha',
#  'bondhu',
#  'baari',
#  'poribar',
#  'dhonnobad',
#  'dukkhito',
#  'baba',
#  'sahajjo',
#  'gach',
#  'maa']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix
import os

def plot_confusion_matrix_from_files(predictions_file, labels_file, save_dir, class_names):
    """Plot a detailed confusion matrix using saved prediction and label files."""
    # Load predictions and labels
    predictions = np.load(predictions_file)
    labels = np.load(labels_file)

    # Generate the confusion matrix
    cm = confusion_matrix(labels, predictions)
    cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.figure(figsize=(14, 14))
    sns.set(font_scale=1.4)  # Adjust font size for better readability
    heatmap = sns.heatmap(cm_normalized, annot=False, cmap="Blues",
                          xticklabels=class_names, yticklabels=class_names,
                          square=True, cbar_kws={"fraction": 0.046, "pad": 0.04})

    heatmap.set_title('Normalized Confusion Matrix')
    heatmap.set_xlabel('Predicted Labels')
    heatmap.set_ylabel('True Labels')
    plt.xticks(rotation=45, ha='right')
    plt.yticks(rotation=0)
    plt.tight_layout()  # Adjust layout to make room for label rotations

    # Save the plot
    plt.savefig(os.path.join(save_dir, 'normalized_confusion_matrix.png'))
    plt.show()

# Example usage
#save_dir = 'your_save_directory'  # Specify your save directory
predictions_file = os.path.join(save_dir, 'predictions.npy')
labels_file = os.path.join(save_dir, 'labels.npy')
#class_names = ['class1', 'class2', 'class3']  # Replace with your actual class names

plot_confusion_matrix_from_files(predictions_file, labels_file, save_dir, class_names)
